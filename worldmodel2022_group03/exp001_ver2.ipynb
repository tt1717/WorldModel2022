# %% [markdown]
# # 2022年 世界モデル 第7回演習
#
# 本演習では, いわゆる世界モデルを用いた強化学習アルゴリズムである **RSSM (Recurrent State Space Model)**[[1]](#scrollTo=J_PCEOJ69prx) と**Dreamer**[[2]](#scrollTo=J_PCEOJ69prx)を実装します.
#
# ## 目次
#
# 1. [準備](#scrollTo=yDN8Ohc0Mh8C)
# 2. [環境の設定](#scrollTo=_eayBK1HPV5H)
# 3. [RSSM](#scrollTo=B3rWEGtkA3e_&line=1&uniqifier=1)
# 4. [RSSMの実装](#scrollTo=xJfU7ygCMeJn)
# 5. [補助機能の実装](#scrollTo=WhlVvU3aZ5FC)
# 6. [Dreamerの実装](#scrollTo=keAW0J-qS24Q)
# 7. [エージェントの実装](#scrollTo=GdKZ1S2_boOd)
# 8. [ハイパーパラメータの設定と学習の準備](#scrollTo=QUPWAkpyc9Z-)
# 9. [学習](#scrollTo=yUoI0l9Ee0Tp)
# 10. [結果の確認](#scrollTo=E3F2tAU0kepm)
# 11. [参考文献](##scrollTo=J_PCEOJ69prx&line=4&uniqifier=1)

# %% [markdown]
# ##1.準備
# まず, 演習を行うために必要な準備を行います.

# %%
import time
import os
import gc

import gym
import pandas as pd

import pathlib
import numpy as np
import matplotlib.pyplot as plt
import imageio
import matplotlib.animation as animation
from IPython.display import HTML
from PIL import Image
from tqdm import tqdm

import torch
from torch.distributions import Normal
from torch.distributions.kl import kl_divergence
from torch import nn
from torch.nn import functional as F
from torch.nn.utils import clip_grad_norm_
from torch.utils.tensorboard import SummaryWriter

# 可視化のためにTensorBoardを用いるので, Colab上でTensorBoardを表示するための宣言を行う
# %load_ext tensorboard

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2.動画の変換

# %%
# base_dir = "/content/gdrive/My Drive/博士課程/world_model_2022/最終課題"
base_dir = "/content/drive/MyDrive/Colab Notebooks/WorldModel/最終課題"
original_img_dir = f"{base_dir}/original_imgs"
src_img_dir = f"{base_dir}/src_imgs"
fps = 30

os.makedirs(original_img_dir, exist_ok=True)
os.makedirs(src_img_dir, exist_ok=True)

# %%
# !ffmpeg -i "$base_dir/shinkansen_480p.mov" -vf fps="$fps" "$original_img_dir/%04d.jpg"
# !ffmpeg -i "$base_dir/IMG_4396.MOV" -vf fps="$fps" "$original_img_dir/%04d.jpg"
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/Colab Notebooks/WorldModel/最終課題/IMG_4396.MOV':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2023-02-11T15:15:30.000000Z
#   Duration: 00:01:11.60, start: 0.000000, bitrate: 3612 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, smpte170m/smpte170m/bt709), 720x1280, 3499 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2023-02-11T15:15:30.000000Z
#       handler_name    : Core Media Video
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 107 kb/s (default)
#     Metadata:
#       creation_time   : 2023-02-11T15:15:30.000000Z
#       handler_name    : Core Media Audio
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5559f2ea6840] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/content/drive/MyDrive/Colab Notebooks/WorldModel/最終課題/original_imgs/%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 720x1280, q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2023-02-11T15:15:30.000000Z
#       handler_name    : Core Media Video
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame= 2148 fps=4.5 q=24.8 Lsize=N/A time=00:01:11.60 bitrate=N/A speed=0.149x
# video:63885kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
original_img_filenames = list(pathlib.Path(original_img_dir).glob('**/*.jpg'))
img_filenames = [str(filename).replace("original", "src") for filename in original_img_filenames]

# %%
img = Image.open(original_img_filenames[0])
img.size
# Out:
# (720, 1280)

# %%
crop = img.crop((0, 200, 800, 1000))
crop.size
# Out:
# (800, 800)

# %%
resize = crop.resize((128,128))
resize
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F38AFB66760>

# %%
# 保存した画像を128x128にクロップ(不使用)
def make_crop_img(img, crop_size=64):
    w, h = img.size[0], img.size[1]
    center = (w // 2, h // 2)
    # (left, uppper, right, bottom)
    crop = img.crop((center[0] - crop_size // 2, center[1] - crop_size // 2, center[0] + crop_size // 2, center[1] + crop_size // 2))
    return crop

# %%
# 保存した画像を定数でクロップして、リサイズする
def make_crop_and_resize_img(img, crop_left, crop_upper, crop_rigt, crop_bottom, size):
    assert (crop_rigt - crop_left) == (crop_bottom - crop_upper)
    # (left, uppper, right, bottom)
    crop = img.crop((crop_left, crop_upper, crop_rigt, crop_bottom))
    resize = crop.resize((size, size))
    return resize

# %%
# クロップ＆サイズ変更
for original_img_filename, img_filename in zip(tqdm(original_img_filenames), img_filenames):
    img = Image.open(original_img_filename)
    # アームと魚を全部入れるために画像の右側をはみ出してクロップする
    crop_img = make_crop_and_resize_img(img, crop_left=0, crop_upper=200, crop_rigt=800, crop_bottom=1000, size=128)
    crop_img.save(img_filename, quality=100)
# Out:
# 100%|██████████| 2148/2148 [04:36<00:00,  7.78it/s]

# %% [markdown]
# 確認のために作成した画像をつなげて動画として再生

# %%
def make_animation_from_images(img_dir):
    img_filenames = list(pathlib.Path(img_dir).glob('**/*.jpg'))
    fig = plt.figure(figsize=(3,3))

    imgs = []
    for img_filename in img_filenames:
        img = plt.imshow(np.asarray(Image.open(img_filename)), animated=True)
        plt.axis('off')
        imgs.append([img])

    anime = animation.ArtistAnimation(fig, imgs, interval=50, repeat_delay=1000)
    plt.close()
    return anime

# %%
HTML(make_animation_from_images(img_dir=src_img_dir).to_html5_video())
# Out:
# <video width="216" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
data = {
    "filename": img_filenames,
    "reward": np.random.rand(len(img_filenames))  # rewardは適当
}
# 1軸想定。2軸以上にするなら色々変更必要。主に次元の扱い。カラムを増やしてもいいし、同一カラム内にタプルで保存してもいい
action_dim = 1
data.update({f"action": np.random.rand(len(img_filenames)) for i in range(1)})
df = pd.DataFrame(data)
df["is_done"] = False
# 適当に100画像ごとにEP完了フラグをつける
df["is_done"].iloc[100::100] = True
df.head(101)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                               filename    reward    action  \
# 0    /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.116218  0.082973
# 1    /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.838852  0.257231
# 2    /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.144653  0.856882
# 3    /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.336852  0.394698
# 4    /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.749769  0.281678
# ..                                                 ...       ...       ...
# 96   /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.919897  0.092505
# 97   /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.476225  0.387216
# 98   /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.274466  0.164961
# 99   /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.497326  0.267345
# 100  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.792396  0.763351
#
#      is_done
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100     True
#
# [101 rows x 4 columns]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## 3.RSSM
# RSSMは以下のパーツに分けることができます.
#
# **Deterministic state model:**
# > $h_{t}=f(h_{t-1}, s_{t-1}, a_{t-1})$
#
# **Stochastic state model:**
# > $s_{t}$ ~ $p(s_{t} | h_{t})$
#
# **Observation model:**
# > $o_{t}$ ~ $p(o_{t} | h_{t}, s_{t})$
#
# **Reward model:**
# > $r_{t}$~ $p(r_{t} | h_{t}, s_{t})$
#
# [以下の画像](https://towardsai.net/p/machine-learning/dreamer-8b5a42acebbf)は1つの時間ステップでのRSSMの挙動を示しています.
#
# ![1stepあたりの模式図](https://cdn-images-1.medium.com/max/1024/1*4b2l7Fr4eavQV5ZMouCT-g.png)
#
#
#
# Deterministic state modelで, RNNは, 前の時間ステップの行動$a_{t-1}$と事後確率状態$s'_{t-1}$, 決定論的状態$h_{t-1}$を入力とし, 決定論的状態$h_t$を出力します.
#
# $h_{t}$は (1)事前状態確率$s_{t}$を計算するために, 1つの隠れ層を持つMLPに供給され (本実装では線形変換）, (2)事後確率状態$s'_{t}$を計算するために, 画像埋め込み$e_t$(本実装では`embedded_obs`と表現される）と連結され, 別の単層MLP(線形変換)に供給されます.
#
# その後, $h_{t}$と$s'_{t}$を連結したものを用いて, 画像や報酬などを再構成します.

# %% [markdown]
# ## 4.RSSMの実装
#
#
# 上記をもとにRSSMの実装を行います. 実装では, 以下の3つのクラスに分けて実装します.
#
# * 状態遷移を担うクラス（TransitionModel）
# * 観測を復元するデコーダクラス（ObservationModel）
# * 報酬を予測するクラス（RewardModel）
#
# ※TransitionModelは上記Deterministic state model, Stochastic state modelを合体させています.

# %% [markdown]
# まず実装するのがTransitionModelです.
#
# 1ステップ先の未来の状態表現を予測する機能を担います.
#
# 学習の方針として, 状態遷移を用いた1ステップ先の未来の状態表現の分布である"prior"と, 1ステップ先の観測の情報を取り込んで計算した状態表現の分布である"posterior"が一致するように学習します.
#
# "posterior"は後に観測の再構成誤差と報酬の予測誤差によって学習されるので, "posterior"は上記の2つの誤差によって妥当な状態表現になるように学習され, 同時に"prior"をそれに近づけることで, 状態表現の空間で未来の予測が可能になるように学習する, というイメージです. よって, これを踏まえたクラスの実装になっています.
#
# 状態表現として, 決定的な状態である"rnn_hidden"と, 確率的な状態である"state"の両方を持っています.

# %%
class TransitionModel(nn.Module):
    """
    このクラスは複数の要素を含んでいます.
    決定的状態遷移 （RNN) : h_t+1 = f(h_t, s_t, a_t)
    確率的状態遷移による1ステップ予測として定義される "prior" : p(s_t+1 | h_t+1)
    観測の情報を取り込んで定義される "posterior": q(s_t+1 | h_t+1, e_t+1)
    """
    def __init__(self, state_dim, action_dim, rnn_hidden_dim,
                 hidden_dim=200, min_stddev=0.1, act=F.elu):
        super(TransitionModel, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.rnn_hidden_dim = rnn_hidden_dim
        self.fc_state_action = nn.Linear(state_dim + action_dim, hidden_dim)

        self.fc_rnn_hidden = nn.Linear(rnn_hidden_dim, hidden_dim)
        self.fc_state_mean_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_rnn_hidden_embedded_obs = nn.Linear(rnn_hidden_dim + 1024, hidden_dim)
        self.fc_state_mean_posterior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_posterior = nn.Linear(hidden_dim, state_dim)

        #next hidden stateを計算
        self.rnn = nn.GRUCell(hidden_dim, rnn_hidden_dim)
        self._min_stddev = min_stddev
        self.act = act


    def forward(self, state, action, rnn_hidden, embedded_next_obs):
        """
        h_t+1 = f(h_t, s_t, a_t)
        prior p(s_t+1 | h_t+1) と posterior q(s_t+1 | h_t+1, e_t+1) を返す
        この2つが近づくように学習する
        """
        next_state_prior, rnn_hidden = self.prior(self.reccurent(state, action, rnn_hidden))
        next_state_posterior = self.posterior(rnn_hidden, embedded_next_obs)
        return next_state_prior, next_state_posterior, rnn_hidden

    def reccurent(self, state, action, rnn_hidden):
        """
        h_t+1 = f(h_t, s_t, a_t)を計算する
        """
        hidden = self.act(self.fc_state_action(torch.cat([state, action], dim=1)))
        #h_t+1を求める
        rnn_hidden = self.rnn(hidden, rnn_hidden)
        return rnn_hidden

    def prior(self, rnn_hidden):
        """
        prior p(s_t+1 | h_t+1) を計算する
        """
        #h_t+1を求める（ヒント: self.act, self.fc_rnn_hiddenを使用）
        hidden = self.act(self.fc_rnn_hidden(rnn_hidden))

        mean = self.fc_state_mean_prior(hidden)
        stddev = F.softplus(self.fc_state_stddev_prior(hidden)) + self._min_stddev
        return Normal(mean, stddev), rnn_hidden

    def posterior(self, rnn_hidden, embedded_obs):
        """
        posterior q(s_t+1 | h_t+1, e_t+1)  を計算する
        """
        # h_t+1, o_t+1を結合し, q(s_t+1 | h_t+1, e_t+1) を計算する
        hidden = self.act(self.fc_rnn_hidden_embedded_obs(torch.cat([rnn_hidden, embedded_obs], dim=1)))
        mean = self.fc_state_mean_posterior(hidden)
        stddev = F.softplus(self.fc_state_stddev_posterior(hidden)) + self._min_stddev
        return Normal(mean, stddev)

# %% [markdown]
# 次に, 観測を再構成するデコーダを実装します.

# %%
class ObservationModel(nn.Module):
    """
    p(o_t | s_t, h_t)
    低次元の状態表現から画像を再構成するデコーダ (3, 64, 64)
    """
    def __init__(self, state_dim, rnn_hidden_dim):
        super(ObservationModel, self).__init__()
        self.fc = nn.Linear(state_dim + rnn_hidden_dim, 1024)
        self.dc1 = nn.ConvTranspose2d(1024, 512, kernel_size=4, stride=4)
        self.dc2 = nn.ConvTranspose2d(512, 256, kernel_size=4, stride=4)
        self.dc3 = nn.ConvTranspose2d(256, 128, kernel_size=4, stride=4)
        self.dc4 = nn.ConvTranspose2d(128, 3, kernel_size=2, stride=2)


    def forward(self, state, rnn_hidden):
        hidden = self.fc(torch.cat([state, rnn_hidden], dim=1))
        hidden = hidden.view(hidden.size(0), 1024, 1, 1)
        hidden = F.relu(self.dc1(hidden))
        hidden = F.relu(self.dc2(hidden))
        hidden = F.relu(self.dc3(hidden))
        obs = self.dc4(hidden)
        return obs

# %% [markdown]
# 次に, 報酬を予測するRewardモデルを実装します.

# %%
class RewardModel(nn.Module):
    """
    p(r_t | s_t, h_t)
    低次元の状態表現から報酬を予測する
    """
    def __init__(self, state_dim, rnn_hidden_dim, hidden_dim=400, act=F.elu):
        super(RewardModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act


    def forward(self, state, rnn_hidden):
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        reward = self.fc4(hidden)
        return reward

# %% [markdown]
# 最後に, 上記で定義された３つのモデルを`RSSM`クラスとしてまとめます.

# %%
class RSSM:
    def __init__(self, state_dim, action_dim, rnn_hidden_dim, ):
        self.transition = TransitionModel(state_dim, action_dim, rnn_hidden_dim).to(device)
        self.observation = ObservationModel(state_dim, rnn_hidden_dim,).to(device)
        self.reward = RewardModel(state_dim, rnn_hidden_dim,).to(device)

# %% [markdown]
# ## 5.補助機能の実装
#
# モデルの実装の前に, いくつか学習上必要になる補助機能を実装しておきましょう. 具体的にはリプレイバッファ, 観測の前処理を行う関数, λ-returnを計算する関数 の3つです.

# %% [markdown]
# まずはリプレイバッファを実装します. ただし, RNNを使う関係上一連の系列として経験をサンプルしてくる必要があるため, DQNの時よりは少し実装に工夫が必要です.

# %%
#　今回のReplayBuffer
class ReplayBuffer(object):
    """
    RNNを用いて訓練するのに適したリプレイバッファ
    """
    def __init__(self, capacity, observation_shape, action_dim):
        self.capacity = capacity

        self.observations = np.zeros((capacity, *observation_shape), dtype=np.uint8)
        self.actions = np.zeros((capacity, action_dim), dtype=np.float32)
        self.rewards = np.zeros((capacity, 1), dtype=np.float32)
        self.done = np.zeros((capacity, 1), dtype=np.bool)

        self.index = 0
        self.is_filled = False

    def push(self, observation, action, reward, done):
        """
        リプレイバッファに経験を追加する
        """
        self.observations[self.index] = observation
        self.actions[self.index] = action
        self.rewards[self.index] = reward
        self.done[self.index] = done

        # indexは巡回し, 最も古い経験を上書きする
        if self.index == self.capacity - 1:
            self.is_filled = True
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size, chunk_length):
        """
        経験をリプレイバッファからサンプルします. （ほぼ）一様なサンプルです
        結果として返ってくるのは観測(画像), 行動, 報酬, 終了シグナルについての(batch_size, chunk_length, 各要素の次元)の配列です
        各バッチは連続した経験になっています
        注意: chunk_lengthをあまり大きな値にすると問題が発生する場合があります
        """
        episode_borders = np.where(self.done)[0]
        sampled_indexes = []
        for _ in range(batch_size):
            cross_border = True
            while cross_border:
                initial_index = np.random.randint(len(self) - chunk_length + 1)
                final_index = initial_index + chunk_length - 1
                cross_border = np.logical_and(initial_index <= episode_borders,
                                              episode_borders < final_index).any()#論理積
            sampled_indexes += list(range(initial_index, final_index + 1))

        sampled_observations = self.observations[sampled_indexes].reshape(
            batch_size, chunk_length, *self.observations.shape[1:])
        sampled_actions = self.actions[sampled_indexes].reshape(
            batch_size, chunk_length, self.actions.shape[1])
        sampled_rewards = self.rewards[sampled_indexes].reshape(
            batch_size, chunk_length, 1)
        sampled_done = self.done[sampled_indexes].reshape(
            batch_size, chunk_length, 1)
        return sampled_observations, sampled_actions, sampled_rewards, sampled_done

    def __len__(self):
        return self.capacity if self.is_filled else self.index

# %% [markdown]
# 次に観測の前処理を行う関数を実装します. これは簡単です. ちなみに, これもラッパーとして最初から適用してしまわないのは, リプレイバッファにはより容量の小さなnp.uint8の形式で保存しておきたいためです.

# %%
def preprocess_obs(obs):
    """
    画像の変換. [0, 255] -> [-0.5, 0.5]
    """
    obs = obs.astype(np.float32)
    normalized_obs = obs / 255.0 - 0.5
    return normalized_obs

# %% [markdown]
# Dreamerでは価値関数の学習を行いますが, このために通常のTD誤差ではなく, **TD(λ)をベースにしたλ-return**としてターゲット価値を計算し, それと現在の予測価値の誤差を用います. そのためにλ-returnを計算する関数をここで実装しておきます.

# %%
def lambda_target(rewards, values, gamma, lambda_):
    """
    価値関数の学習のためのλ-returnを計算します
    """
    V_lambda = torch.zeros_like(rewards, device=rewards.device)

    H = rewards.shape[0] - 1
    V_n = torch.zeros_like(rewards, device=rewards.device)
    V_n[H] = values[H]
    for n in range(1, H+1):
        # まずn-step returnを計算します
        # 注意: 系列が途中で終わってしまったら, 可能な中で最大のnを用いたn-stepを使います
        V_n[:-n] = (gamma ** n) * values[n:]
        for k in range(1, n+1):
            if k == n:
                V_n[:-n] += (gamma ** (n-1)) * rewards[k:]
            else:
                V_n[:-n] += (gamma ** (k-1)) * rewards[k:-n+k]

        # lambda_でn-step returnを重みづけてλ-returnを計算します
        if n == H:
            V_lambda += (lambda_ ** (H-1)) * V_n
        else:
            V_lambda += (1 - lambda_) * (lambda_ ** (n-1)) * V_n

    return V_lambda

# %% [markdown]
# ## 6.Dreamerの実装
#
# 続いてDreamerの実装です.Dreamerの実装では以下の3クラスは上で定義したRSSMの各クラスと同義ですので,
# 改めて定義はしておらず`RSSM`クラスを呼び出して使用することとします.
# * 状態遷移を担うクラス(TransitionModel)
# * 観測を復元するデコーダクラス(ObservationModel)
# * 報酬を予測するクラス(RewardModel)
#
#
# そのため,新たに定義するモデルは, 以下の３つのみになります.
# * 観測の画像をベクトルに変換するエンコーダクラス(Encoder)
# * 価値関数を計算するクラス(ValueModel)
# * 実際に行動を決定するクラス(ActionModel)

# %% [markdown]
# まずエンコーダを実装します. ここでは, CNN(Convolutional Neural Network)を用いて, 観測の画像をベクトルに変換します.

# %%
class Encoder(nn.Module):
    """
    (3, 128, 128)の画像を(1024,)のベクトルに変換するエンコーダ
    """
    def __init__(self):
        super(Encoder, self).__init__()
        self.cv1 = nn.Conv2d(3, 32, kernel_size=4, stride=2)
        self.cv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.cv3 = nn.Conv2d(64, 128, kernel_size=4, stride=2)
        self.cv4 = nn.Conv2d(128, 256, kernel_size=4, stride=2)
        self.cv5 = nn.Conv2d(256, 256, kernel_size=4, stride=2)

    def forward(self, obs):
        hidden = F.relu(self.cv1(obs))
        hidden = F.relu(self.cv2(hidden))
        hidden = F.relu(self.cv3(hidden))
        hidden = F.relu(self.cv4(hidden))
        embedded_obs = F.relu(self.cv5(hidden)).reshape(hidden.size(0), -1)
        return embedded_obs

# %% [markdown]
# ここからがDreamerの中核となる部分で, RSSMの学習を通して獲得された低次元の状態表現の上でActor-Criticを行います.

# %% [markdown]
# 以下で, 価値関数を近似するValueモデル $v_{\phi}(s_{\tau})　\approx E_{q(.|s_{\tau})}(\sum_{\tau=t}^{t+H}(\gamma^{\tau-t}r_{\tau}) )$ を実装します. Q学習などで用いられる状態行動価値関数Q(s, a)ではなく, 状態価値関数V(s)であることに多少の注意が必要です.

# %%
class ValueModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から状態価値を出力する
    """
    def __init__(self, state_dim, rnn_hidden_dim, hidden_dim=400, act=F.elu):
        super(ValueModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act

    def forward(self, state, rnn_hidden):
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        state_value = self.fc4(hidden)
        return state_value

# %% [markdown]
# 最後です. 実際に行動を出力するActionモデル $a_{\tau} \sim q_{\delta}(a_{\tau}|s_{\tau})$ を実装します.
#
# Actionモデルは価値の見積もりを最大化することを目的とします.

# %%
class ActionModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から行動を計算するクラス
    """
    def __init__(self, state_dim, rnn_hidden_dim, action_dim,
                 hidden_dim=400, act=F.elu, min_stddev=1e-4, init_stddev=5.0):
        super(ActionModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.fc_mean = nn.Linear(hidden_dim, action_dim)
        self.fc_stddev = nn.Linear(hidden_dim, action_dim)
        self.act = act
        self.min_stddev = min_stddev
        self.init_stddev = np.log(np.exp(init_stddev) - 1)

    def forward(self, state, rnn_hidden, training=True):
        """
        training=Trueなら, NNのパラメータに関して微分可能な形の行動のサンプル（Reparametrizationによる）を返します
        training=Falseなら, 行動の確率分布の平均値を返します
        """
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        hidden = self.act(self.fc4(hidden))

        # Dreamerの実装に合わせて少し平均と分散に対する簡単な変換が入っています
        mean = self.fc_mean(hidden)
        mean = 5.0 * torch.tanh(mean / 5.0)
        stddev = self.fc_stddev(hidden)
        stddev = F.softplus(stddev + self.init_stddev) + self.min_stddev

        if training:
            action = torch.tanh(Normal(mean, stddev).rsample())#微分可能にするためrsample()
        else:
            action = torch.tanh(mean)
        return action

# %% [markdown]
# 実装の詳細まで掴みきれなくとも, 個々のクラスが担っている役割が大雑把にでもわかっていただければ幸いです.

# %% [markdown]
# ## 7.エージェントの実装
#
# Dreamerでは行動を計算するために低次元の状態表現が必要で, この状態表現はRSSMを用いて計算されるため, テスト時もこの状態表現のためにRSSMによる推論を行い続ける必要があります.
#
# そのため, 先ほど実装したActionModelをそのまま使っても簡単には行動を決定できません.
#
# ここを扱いやすくするために, RSSMを使って低次元の状態表現を計算しつつ, 行動を決定するAgentクラスを実装します.

# %%
class Agent:
    """
    ActionModelに基づき行動を決定する. そのためにRSSMを用いて状態表現をリアルタイムで推論して維持するクラス
    """
    def __init__(self, encoder, rssm, action_model):
        self.encoder = encoder
        self.rssm = rssm
        self.action_model = action_model

        self.device = next(self.action_model.parameters()).device
        self.rnn_hidden = torch.zeros(1, rssm.rnn_hidden_dim, device=self.device)

    def __call__(self, obs, training=True):
        # preprocessを適用, PyTorchのためにChannel-Firstに変換
        obs = preprocess_obs(obs)
        obs = torch.as_tensor(obs, device=self.device)
        obs = obs.transpose(1, 2).transpose(0, 1).unsqueeze(0)

        with torch.no_grad():
            # 観測を低次元の表現に変換し, posteriorからのサンプルをActionModelに入力して行動を決定する
            embedded_obs = self.encoder(obs)
            state_posterior = self.rssm.posterior(self.rnn_hidden, embedded_obs)
            state = state_posterior.sample()
            action = self.action_model(state, self.rnn_hidden, training=training)

            # 次のステップのためにRNNの隠れ状態を更新しておく
            _, self.rnn_hidden = self.rssm.prior(self.rssm.reccurent(state, action, self.rnn_hidden))

        return action.squeeze().cpu().numpy()

    #RNNの隠れ状態をリセット
    def reset(self):
        self.rnn_hidden = torch.zeros(1, self.rssm.rnn_hidden_dim, device=self.device)

# %% [markdown]
# ## 8.ハイパーパラメータの設定と学習の準備
#
# ここまででDreamerの基本的な構成要素は実装が終わりました. あとはハイパーパラメータを設定し, モデルやリプレイバッファを宣言して学習の準備を整えます.

# %%
# リプレイバッファの宣言
buffer_capacity = 200000  # Colabのメモリの都合上, 元の実装より小さめにとっています
replay_buffer = ReplayBuffer(capacity=buffer_capacity,
                              observation_shape=(128, 128, 3),  # env.observation_space.shape,
                              action_dim=1)

# モデルの宣言
state_dim = 30  # 確率的状態の次元
rnn_hidden_dim = 200  # 決定的状態（RNNの隠れ状態）の次元
#確率的状態の次元と決定的状態（RNNの隠れ状態）の次元は一致しなくて良い
encoder = Encoder().to(device)
rssm = RSSM(state_dim, action_dim, rnn_hidden_dim)
value_model = ValueModel(state_dim, rnn_hidden_dim).to(device)
action_model = ActionModel(state_dim, rnn_hidden_dim, action_dim).to(device)

# オプティマイザの宣言
model_lr = 6e-4  # encoder, rssm, obs_model, reward_modelの学習率
value_lr = 8e-5
action_lr = 8e-5
eps = 1e-4
model_params = (list(encoder.parameters()) +
                  list(rssm.transition.parameters()) +
                  list(rssm.observation.parameters()) +
                  list(rssm.reward.parameters()))
model_optimizer = torch.optim.Adam(model_params, lr=model_lr, eps=eps)
value_optimizer = torch.optim.Adam(value_model.parameters(), lr=value_lr, eps=eps)
action_optimizer = torch.optim.Adam(action_model.parameters(), lr=action_lr, eps=eps)

# その他ハイパーパラメータ
# seed_episodes = 5  # 最初にランダム行動で探索するエピソード数
# all_episodes = 20  # 学習全体のエピソード数（300ほどで, ある程度収束します）
test_interval = 5  # 何エピソードごとに探索ノイズなしのテストを行うか
model_save_interval = 20  # NNの重みを何エピソードごとに保存するか
collect_interval = 100  # 何回のNNの更新ごとに経験を集めるか（＝1エピソード経験を集めるごとに何回更新するか）

action_noise_var = 0.3  # 探索ノイズの強さ

batch_size = 20
chunk_length = 30  # 1回の更新で用いる系列の長さ
imagination_horizon = 15  # Actor-Criticの更新のために, Dreamerで何ステップ先までの想像上の軌道を生成するか


gamma = 0.9  # 割引率
lambda_ = 0.95  # λ-returnのパラメータ
clip_grad_norm = 100  # gradient clippingの値
free_nats = 3  # KL誤差（RSSMのTransitionModelにおけるpriorとposteriorの間の誤差）がこの値以下の場合, 無視する
# Out:
# <ipython-input-8-1a37dc8b0d1d>:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.done = np.zeros((capacity, 1), dtype=np.bool)

# %% [markdown]
# ## 9.学習
# まず, 最初の数エピソードはランダムに行動して経験をリプレイバッファに貯めます.

# %%
df.head()
# Out:
#                                             filename    reward    action  \
# 0  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.116218  0.082973
# 1  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.838852  0.257231
# 2  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.144653  0.856882
# 3  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.336852  0.394698
# 4  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.749769  0.281678
#
#    is_done
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
# 動作確認せる
_df = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [6, 7, 8, 9, 10], 'is_done': [False, False, True, False, True]})

# is_done列がTrueの場所までの行でデータフレームを分割して、リストに格納する
split_dfs = []
start_idx = 0
for end_idx in _df.loc[_df['is_done']==True].index:
    split_dfs.append(_df.iloc[start_idx:end_idx+1])
    start_idx = end_idx+1
split_dfs[0]
# Out:
#    A  B  is_done
# 0  1  6    False
# 1  2  7    False
# 2  3  8     True

# %%
# dataframeをエピソードが完了する単位で分割する
split_dfs = []
start_idx = 0
for end_idx in df.loc[df['is_done']==True].index:
    split_dfs.append(df.iloc[start_idx:end_idx+1])
    start_idx = end_idx+1
print(len(split_dfs))
# Out:
# 21

# %%
split_dfs[10].head()
# Out:
#                                                filename    reward    action  \
# 1001  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.347565  0.177663
# 1002  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.431568  0.420715
# 1003  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.781321  0.216678
# 1004  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.749024  0.803420
# 1005  /content/drive/MyDrive/Colab Notebooks/WorldMo...  0.092821  0.179902
#
#       is_done
# 1001    False
# 1002    False
# 1003    False
# 1004    False
# 1005    False

# %%
for split_df in split_dfs:
    for idx, row in split_df.iterrows():
        if idx == 0:
            # 最初のobsは過去のアクションがないので特別扱い
            obs = Image.open(row.filename)
            continue
        # 今の観測は一つ前のタイムステップでのアクションの結果なのでnex_obs
        next_obs = Image.open(row.filename)
        # actionは複数次元になるならここで変える
        action = row.action
        reward = row.reward
        done = row.is_done
        replay_buffer.push(obs, action, reward, done)
        # 今のタイムステップのnext_obsは次のタイムステップのobsとなる
        obs = next_obs

# %% [markdown]
# 学習結果を確認するために, TensorBoardを立ち上げておきます.

# %%
log_dir = base_dir + '/logs'
writer = SummaryWriter(log_dir)
#%tensorboard --logdir='./logs'

# %% [markdown]
# 以下がメインの学習ループです. それぞれのコメントを見て, 実装の内容を追ってください.
#
# 学習にはColab Proで3時間半ぐらいの時間がかかります.

# %%
for episode, split_df in enumerate(split_dfs):
    start = time.time()
    # 行動を決定するためのエージェントを宣言
    policy = Agent(encoder, rssm.transition, action_model)
    total_reward = 0
    for idx, row in split_df.iterrows():
        if idx == 0:
            # 最初のobsは過去のアクションがないので特別扱い
            obs = Image.open(row.filename)
            continue
        # 今の観測は一つ前のタイムステップでのアクションの結果なのでnex_obs
        next_obs = Image.open(row.filename)
        # actionは複数次元になるならここで変える
        action = row.action
        reward = row.reward
        done = row.is_done
        replay_buffer.push(obs, action, reward, done)
        # 今のタイムステップのnext_obsは次のタイムステップのobsとなる
        obs = next_obs
        total_reward += reward

    # 訓練時の報酬と経過時間をログとして表示
    writer.add_scalar('total reward at train', total_reward, episode)
    print('episode [%4d/%4d] is collected. Total reward is %f' %
            (episode+1, len(split_dfs), total_reward))
    print('elasped time for interaction: %.2fs' % (time.time() - start))

    # NNのパラメータを更新する
    start = time.time()
    for update_step in range(collect_interval):
        # -------------------------------------------------------------------------------------
        #  RSSM(trainsition_model, obs_model, reward_model)の更新 - Dynamics learning
        # -------------------------------------------------------------------------------------
        observations, actions, rewards, _ = \
            replay_buffer.sample(batch_size, chunk_length)

        # 観測を前処理し, RNNを用いたPyTorchでの学習のためにTensorの次元を調整
        observations = preprocess_obs(observations)
        observations = torch.as_tensor(observations, device=device)
        observations = observations.transpose(3, 4).transpose(2, 3)
        observations = observations.transpose(0, 1)
        actions = torch.as_tensor(actions, device=device).transpose(0, 1)
        rewards = torch.as_tensor(rewards, device=device).transpose(0, 1)

        # 観測をエンコーダで低次元のベクトルに変換
        embedded_observations = encoder(
            observations.reshape(-1, 3, 128, 128)).view(chunk_length, batch_size, -1)

        # 低次元の状態表現を保持しておくためのTensorを定義
        states = torch.zeros(chunk_length, batch_size, state_dim, device=device)
        rnn_hiddens = torch.zeros(chunk_length, batch_size, rnn_hidden_dim, device=device)

        # 低次元の状態表現は最初はゼロ初期化（timestep１つ分）
        state = torch.zeros(batch_size, state_dim, device=device)
        rnn_hidden = torch.zeros(batch_size, rnn_hidden_dim, device=device)

        # 状態s_tの予測を行ってそのロスを計算する（priorとposteriorの間のKLダイバージェンス）
        kl_loss = 0
        for l in range(chunk_length-1):
            next_state_prior, next_state_posterior, rnn_hidden = \
                rssm.transition(state, actions[l], rnn_hidden, embedded_observations[l+1])
            state = next_state_posterior.rsample()
            states[l+1] = state
            rnn_hiddens[l+1] = rnn_hidden
            kl = kl_divergence(next_state_prior, next_state_posterior).sum(dim=1)  # WRITE ME （ヒント: kl_divergence()を使用）
            kl_loss += kl.clamp(min=free_nats).mean()  # 原論文通り, KL誤差がfree_nats以下の時は無視
        kl_loss /= (chunk_length - 1)

        # states[0] and rnn_hiddens[0]はゼロ初期化なので以降では使わない
        # states, rnn_hiddensは低次元の状態表現
        states = states[1:]
        rnn_hiddens = rnn_hiddens[1:]

        # 観測を再構成, また, 報酬を予測
        flatten_states = states.view(-1, state_dim)
        flatten_rnn_hiddens = rnn_hiddens.view(-1, rnn_hidden_dim)
        recon_observations = rssm.observation(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 3, 128, 128)
        predicted_rewards = rssm.reward(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 1)

        # 観測と報酬の予測誤差を計算
        obs_loss = 0.5 * F.mse_loss(recon_observations, observations[1:], reduction='none').mean([0, 1]).sum()
        reward_loss = 0.5 * F.mse_loss(predicted_rewards, rewards[:-1])

        # 以上のロスを合わせて勾配降下で更新する
        model_loss = kl_loss + obs_loss + reward_loss
        model_optimizer.zero_grad()
        model_loss.backward()
        clip_grad_norm_(model_params, clip_grad_norm)
        model_optimizer.step()

        # --------------------------------------------------
        #  Action Model, Value　Modelの更新　- Behavior leaning
        # --------------------------------------------------
        # Actor-Criticのロスで他のモデルを更新することはないので勾配の流れを一度遮断
        # flatten_states, flatten_rnn_hiddensは RSSMから得られた低次元の状態表現を平坦化した値
        flatten_states = flatten_states.detach()
        flatten_rnn_hiddens = flatten_rnn_hiddens.detach()

        # DreamerにおけるActor-Criticの更新のために, 現在のモデルを用いた
        # 数ステップ先の未来の状態予測を保持するためのTensorを用意
        imaginated_states = torch.zeros(imagination_horizon + 1,
                                         *flatten_states.shape,
                                          device=flatten_states.device)
        imaginated_rnn_hiddens = torch.zeros(imagination_horizon + 1,
                                                *flatten_rnn_hiddens.shape,
                                                device=flatten_rnn_hiddens.device)

        #　未来予測をして想像上の軌道を作る前に, 最初の状態としては先ほどモデルの更新で使っていた
        # リプレイバッファからサンプルされた観測データを取り込んだ上で推論した状態表現を使う
        imaginated_states[0] = flatten_states
        imaginated_rnn_hiddens[0] = flatten_rnn_hiddens

        # open-loopで未来の状態予測を使い, 想像上の軌道を作る
        for h in range(1, imagination_horizon + 1):
            # 行動はActionModelで決定. この行動はモデルのパラメータに対して微分可能で,
            #　これを介してActionModelは更新される
            actions = action_model(flatten_states, flatten_rnn_hiddens)
            flatten_states_prior, flatten_rnn_hiddens = rssm.transition.prior(rssm.transition.reccurent(flatten_states,
                                                                   actions,
                                                                   flatten_rnn_hiddens))
            flatten_states = flatten_states_prior.rsample()
            imaginated_states[h] = flatten_states
            imaginated_rnn_hiddens[h] = flatten_rnn_hiddens

        # RSSMのreward_modelにより予測された架空の軌道に対する報酬を計算
        flatten_imaginated_states = imaginated_states.view(-1, state_dim)
        flatten_imaginated_rnn_hiddens = imaginated_rnn_hiddens.view(-1, rnn_hidden_dim)
        imaginated_rewards = \
            rssm.reward(flatten_imaginated_states,
                        flatten_imaginated_rnn_hiddens).view(imagination_horizon + 1, -1)
        imaginated_values = \
            value_model(flatten_imaginated_states,
                        flatten_imaginated_rnn_hiddens).view(imagination_horizon + 1, -1)

        # λ-returnのターゲットを計算(V_{\lambda}(s_{\tau})
        lambda_target_values = lambda_target(imaginated_rewards, imaginated_values, gamma, lambda_)

        # 価値関数の予測した価値が大きくなるようにActionModelを更新
        # PyTorchの基本は勾配降下だが, 今回は大きくしたいので-1をかける
        action_loss = -lambda_target_values.mean()
        action_optimizer.zero_grad()
        action_loss.backward()
        clip_grad_norm_(action_model.parameters(), clip_grad_norm)
        action_optimizer.step()

        # TD(λ)ベースの目的関数で価値関数を更新（価値関数のみを学習するため，学習しない変数のグラフは切っている. )
        imaginated_values = value_model(flatten_imaginated_states.detach(), flatten_imaginated_rnn_hiddens.detach()).view(imagination_horizon + 1, -1)
        value_loss = 0.5 * F.mse_loss(imaginated_values, lambda_target_values.detach())  # WRITE ME （ヒント: 0.5 * F.mse_loss()を使用）
        value_optimizer.zero_grad()
        value_loss.backward()
        clip_grad_norm_(value_model.parameters(), clip_grad_norm)
        value_optimizer.step()

        # ログをTensorBoardに出力
        print('update_step: %3d model loss: %.5f, kl_loss: %.5f, '
             'obs_loss: %.5f, reward_loss: %.5f, '
             'value_loss: %.5f action_loss: %.5f'
                % (update_step + 1, model_loss.item(), kl_loss.item(),
                    obs_loss.item(), reward_loss.item(),
                    value_loss.item(), action_loss.item()))
        total_update_step = episode * collect_interval + update_step
        writer.add_scalar('model loss', model_loss.item(), total_update_step)
        writer.add_scalar('kl loss', kl_loss.item(), total_update_step)
        writer.add_scalar('obs loss', obs_loss.item(), total_update_step)
        writer.add_scalar('reward loss', reward_loss.item(), total_update_step)
        writer.add_scalar('value loss', value_loss.item(), total_update_step)
    writer.add_scalar('action loss', action_loss.item(), total_update_step)

    print('elasped time for update: %.2fs' % (time.time() - start))

    # --------------------------------------------------------------
    #    テストフェーズ. 探索ノイズなしでの性能を評価する
    # --------------------------------------------------------------
    # if (episode + 1) % test_interval == 0:
    #     policy = Agent(encoder, rssm.transition, action_model)
    #     start = time.time()
    #     obs = env.reset()
    #     done = False
    #     total_reward = 0
    #     while not done:
    #         action = policy(obs, training=False)
    #         obs, reward, done, _ = env.step(action)
    #         total_reward += reward

    #     writer.add_scalar('total reward at test', total_reward, episode)
    #     print('Total test reward at episode [%4d/%4d] is %f' %
    #             (episode+1, all_episodes, total_reward))
    #     print('elasped time for test: %.2fs' % (time.time() - start))

    if (episode + 1) % model_save_interval == 0:
        # 定期的に学習済みモデルのパラメータを保存する
        model_log_dir = os.path.join(log_dir, 'episode_%04d' % (episode + 1))
        os.makedirs(model_log_dir)
        torch.save(encoder.state_dict(), os.path.join(model_log_dir, 'encoder.pth'))
        torch.save(rssm.transition.state_dict(), os.path.join(model_log_dir, 'rssm.pth'))
        torch.save(rssm.observation.state_dict(), os.path.join(model_log_dir, 'obs_model.pth'))
        torch.save(rssm.reward.state_dict(), os.path.join(model_log_dir, 'reward_model.pth'))
        torch.save(value_model.state_dict(), os.path.join(model_log_dir, 'value_model.pth'))
        torch.save(action_model.state_dict(), os.path.join(model_log_dir, 'action_model.pth'))
    gc.collect()

writer.close()
# Out:
# episode [   1/  21] is collected. Total reward is 52.283466
# elasped time for interaction: 0.20s
# update_step:   1 model loss: 30.88195, kl_loss: 4.23926, obs_loss: 26.60168, reward_loss: 0.04101, value_loss: 0.00498 action_loss: -5.02616
# update_step:   2 model loss: 37.37331, kl_loss: 4.36943, obs_loss: 32.96403, reward_loss: 0.03985, value_loss: 0.00981 action_loss: -5.03563
# update_step:   3 model loss: 34.23600, kl_loss: 4.35302, obs_loss: 29.84024, reward_loss: 0.04274, value_loss: 0.00814 action_loss: -5.03299
# update_step:   4 model loss: 32.28134, kl_loss: 4.08127, obs_loss: 28.15748, reward_loss: 0.04258, value_loss: 0.00837 action_loss: -5.00032
# update_step:   5 model loss: 30.27122, kl_loss: 3.75558, obs_loss: 26.47188, reward_loss: 0.04376, value_loss: 0.00832 action_loss: -5.04102
# update_step:   6 model loss: 34.11279, kl_loss: 4.11474, obs_loss: 29.95637, reward_loss: 0.04168, value_loss: 0.00822 action_loss: -4.93952
# update_step:   7 model loss: 34.37107, kl_loss: 4.00341, obs_loss: 30.32839, reward_loss: 0.03926, value_loss: 0.00267 action_loss: -5.04620
# update_step:   8 model loss: 34.79010, kl_loss: 4.16793, obs_loss: 30.58182, reward_loss: 0.04035, value_loss: 0.00366 action_loss: -5.06754
# update_step:   9 model loss: 33.78992, kl_loss: 3.98132, obs_loss: 29.76778, reward_loss: 0.04083, value_loss: 0.00458 action_loss: -5.10458
# update_step:  10 model loss: 34.45378, kl_loss: 4.28086, obs_loss: 30.13348, reward_loss: 0.03944, value_loss: 0.00946 action_loss: -5.15712
# update_step:  11 model loss: 33.80706, kl_loss: 4.10688, obs_loss: 29.65947, reward_loss: 0.04071, value_loss: 0.01071 action_loss: -5.16135
# update_step:  12 model loss: 32.67744, kl_loss: 3.95340, obs_loss: 28.68210, reward_loss: 0.04193, value_loss: 0.01128 action_loss: -5.23904
# update_step:  13 model loss: 30.48009, kl_loss: 4.03963, obs_loss: 26.40152, reward_loss: 0.03894, value_loss: 0.00576 action_loss: -5.18680
# update_step:  14 model loss: 31.51821, kl_loss: 3.99310, obs_loss: 27.48340, reward_loss: 0.04171, value_loss: 0.00360 action_loss: -5.22707
# update_step:  15 model loss: 32.56977, kl_loss: 4.12350, obs_loss: 28.40449, reward_loss: 0.04179, value_loss: 0.00296 action_loss: -5.25557
# update_step:  16 model loss: 31.73185, kl_loss: 4.03105, obs_loss: 27.65871, reward_loss: 0.04210, value_loss: 0.00187 action_loss: -5.26867
# update_step:  17 model loss: 33.42492, kl_loss: 4.16492, obs_loss: 29.22023, reward_loss: 0.03978, value_loss: 0.00247 action_loss: -5.27733
# update_step:  18 model loss: 32.96613, kl_loss: 4.19030, obs_loss: 28.73709, reward_loss: 0.03874, value_loss: 0.00346 action_loss: -5.25232
# update_step:  19 model loss: 35.70876, kl_loss: 4.35147, obs_loss: 31.31431, reward_loss: 0.04297, value_loss: 0.00523 action_loss: -5.22993
# update_step:  20 model loss: 37.93187, kl_loss: 4.43002, obs_loss: 33.46198, reward_loss: 0.03988, value_loss: 0.00628 action_loss: -5.18238
# update_step:  21 model loss: 33.49131, kl_loss: 4.18866, obs_loss: 29.26101, reward_loss: 0.04164, value_loss: 0.00641 action_loss: -5.20817
# update_step:  22 model loss: 35.95967, kl_loss: 4.41788, obs_loss: 31.50058, reward_loss: 0.04121, value_loss: 0.00753 action_loss: -5.19797
# update_step:  23 model loss: 35.33249, kl_loss: 4.19720, obs_loss: 31.09492, reward_loss: 0.04037, value_loss: 0.00758 action_loss: -5.25062
# update_step:  24 model loss: 31.39273, kl_loss: 4.12652, obs_loss: 27.22808, reward_loss: 0.03812, value_loss: 0.00471 action_loss: -5.26318
# update_step:  25 model loss: 32.72440, kl_loss: 4.36265, obs_loss: 28.31980, reward_loss: 0.04194, value_loss: 0.00280 action_loss: -5.21677
# update_step:  26 model loss: 31.37595, kl_loss: 4.08370, obs_loss: 27.25182, reward_loss: 0.04042, value_loss: 0.00166 action_loss: -5.19326
# update_step:  27 model loss: 30.26527, kl_loss: 3.95677, obs_loss: 26.26676, reward_loss: 0.04174, value_loss: 0.00263 action_loss: -5.28536
# update_step:  28 model loss: 30.84410, kl_loss: 3.99180, obs_loss: 26.81016, reward_loss: 0.04215, value_loss: 0.00697 action_loss: -5.33374
# update_step:  29 model loss: 32.96805, kl_loss: 4.32154, obs_loss: 28.60643, reward_loss: 0.04008, value_loss: 0.00813 action_loss: -5.21973
# update_step:  30 model loss: 32.80800, kl_loss: 4.16513, obs_loss: 28.60103, reward_loss: 0.04184, value_loss: 0.00733 action_loss: -5.21681
# update_step:  31 model loss: 34.30635, kl_loss: 4.47204, obs_loss: 29.79255, reward_loss: 0.04176, value_loss: 0.00451 action_loss: -5.21781
# update_step:  32 model loss: 30.53795, kl_loss: 4.30738, obs_loss: 26.18754, reward_loss: 0.04303, value_loss: 0.00239 action_loss: -5.25942
# update_step:  33 model loss: 29.95781, kl_loss: 4.07134, obs_loss: 25.84349, reward_loss: 0.04299, value_loss: 0.00178 action_loss: -5.28651
# update_step:  34 model loss: 31.07739, kl_loss: 3.97924, obs_loss: 27.05569, reward_loss: 0.04246, value_loss: 0.00199 action_loss: -5.30643
# update_step:  35 model loss: 35.60432, kl_loss: 4.26021, obs_loss: 31.30176, reward_loss: 0.04235, value_loss: 0.00276 action_loss: -5.24951
# update_step:  36 model loss: 31.99140, kl_loss: 4.21303, obs_loss: 27.73844, reward_loss: 0.03993, value_loss: 0.00315 action_loss: -5.25111
# update_step:  37 model loss: 31.05288, kl_loss: 4.16688, obs_loss: 26.84351, reward_loss: 0.04249, value_loss: 0.00290 action_loss: -5.25983
# update_step:  38 model loss: 31.70926, kl_loss: 4.18480, obs_loss: 27.48284, reward_loss: 0.04162, value_loss: 0.00332 action_loss: -5.26820
# update_step:  39 model loss: 29.18269, kl_loss: 4.04158, obs_loss: 25.09957, reward_loss: 0.04154, value_loss: 0.00341 action_loss: -5.26057
# update_step:  40 model loss: 33.36333, kl_loss: 4.03608, obs_loss: 29.28590, reward_loss: 0.04136, value_loss: 0.00285 action_loss: -5.24098
# update_step:  41 model loss: 31.91753, kl_loss: 4.23524, obs_loss: 27.64279, reward_loss: 0.03951, value_loss: 0.00289 action_loss: -5.25017
# update_step:  42 model loss: 30.50345, kl_loss: 4.20611, obs_loss: 26.25838, reward_loss: 0.03897, value_loss: 0.00182 action_loss: -5.23252
# update_step:  43 model loss: 31.80406, kl_loss: 4.19723, obs_loss: 27.56571, reward_loss: 0.04113, value_loss: 0.00290 action_loss: -5.20981
# update_step:  44 model loss: 31.15491, kl_loss: 4.26050, obs_loss: 26.85430, reward_loss: 0.04011, value_loss: 0.00425 action_loss: -5.29061
# update_step:  45 model loss: 31.38050, kl_loss: 4.11601, obs_loss: 27.22160, reward_loss: 0.04289, value_loss: 0.00618 action_loss: -5.28003
# update_step:  46 model loss: 32.60110, kl_loss: 4.05739, obs_loss: 28.50381, reward_loss: 0.03991, value_loss: 0.00638 action_loss: -5.23031
# update_step:  47 model loss: 32.54273, kl_loss: 4.46630, obs_loss: 28.03572, reward_loss: 0.04072, value_loss: 0.00684 action_loss: -5.21071
# update_step:  48 model loss: 31.31684, kl_loss: 3.99230, obs_loss: 27.28370, reward_loss: 0.04083, value_loss: 0.00871 action_loss: -5.31624
# update_step:  49 model loss: 30.14991, kl_loss: 3.97102, obs_loss: 26.13881, reward_loss: 0.04008, value_loss: 0.00906 action_loss: -5.35193
# update_step:  50 model loss: 34.08678, kl_loss: 4.31117, obs_loss: 29.73521, reward_loss: 0.04040, value_loss: 0.00849 action_loss: -5.41344
# update_step:  51 model loss: 36.42342, kl_loss: 4.23168, obs_loss: 32.15274, reward_loss: 0.03901, value_loss: 0.00761 action_loss: -5.44620
# update_step:  52 model loss: 30.00886, kl_loss: 3.99256, obs_loss: 25.97596, reward_loss: 0.04034, value_loss: 0.00444 action_loss: -5.50401
# update_step:  53 model loss: 27.22397, kl_loss: 4.08699, obs_loss: 23.09200, reward_loss: 0.04497, value_loss: 0.00147 action_loss: -5.54743
# update_step:  54 model loss: 31.98293, kl_loss: 3.97574, obs_loss: 27.96605, reward_loss: 0.04113, value_loss: 0.00547 action_loss: -5.50551
# update_step:  55 model loss: 33.12864, kl_loss: 4.28364, obs_loss: 28.80642, reward_loss: 0.03858, value_loss: 0.01348 action_loss: -5.44631
# update_step:  56 model loss: 33.03561, kl_loss: 4.26386, obs_loss: 28.73245, reward_loss: 0.03929, value_loss: 0.01836 action_loss: -5.46796
# update_step:  57 model loss: 30.34633, kl_loss: 4.24962, obs_loss: 26.05222, reward_loss: 0.04449, value_loss: 0.01943 action_loss: -5.43864
# update_step:  58 model loss: 36.16119, kl_loss: 4.37086, obs_loss: 31.74968, reward_loss: 0.04065, value_loss: 0.02158 action_loss: -5.37614
# update_step:  59 model loss: 37.34288, kl_loss: 4.34313, obs_loss: 32.95800, reward_loss: 0.04175, value_loss: 0.01623 action_loss: -5.41414
# update_step:  60 model loss: 33.87458, kl_loss: 4.10880, obs_loss: 29.72501, reward_loss: 0.04077, value_loss: 0.01245 action_loss: -5.34322
# update_step:  61 model loss: 31.94427, kl_loss: 4.19891, obs_loss: 27.70608, reward_loss: 0.03928, value_loss: 0.00423 action_loss: -5.37148
# update_step:  62 model loss: 30.73465, kl_loss: 4.21138, obs_loss: 26.47970, reward_loss: 0.04357, value_loss: 0.00248 action_loss: -5.28316
# update_step:  63 model loss: 29.44381, kl_loss: 4.26380, obs_loss: 25.13839, reward_loss: 0.04162, value_loss: 0.00351 action_loss: -5.20711
# update_step:  64 model loss: 31.28790, kl_loss: 4.26018, obs_loss: 26.98752, reward_loss: 0.04019, value_loss: 0.00744 action_loss: -5.17189
# update_step:  65 model loss: 32.20898, kl_loss: 4.42225, obs_loss: 27.74660, reward_loss: 0.04013, value_loss: 0.01344 action_loss: -5.22174
# update_step:  66 model loss: 32.81443, kl_loss: 4.48347, obs_loss: 28.28785, reward_loss: 0.04312, value_loss: 0.01667 action_loss: -5.20766
# update_step:  67 model loss: 30.22042, kl_loss: 4.12567, obs_loss: 26.05613, reward_loss: 0.03862, value_loss: 0.01866 action_loss: -5.20332
# update_step:  68 model loss: 31.26487, kl_loss: 4.29630, obs_loss: 26.92810, reward_loss: 0.04047, value_loss: 0.01759 action_loss: -5.27473
# update_step:  69 model loss: 31.53486, kl_loss: 4.13282, obs_loss: 27.36071, reward_loss: 0.04132, value_loss: 0.01475 action_loss: -5.38946
# update_step:  70 model loss: 33.02001, kl_loss: 4.29484, obs_loss: 28.68406, reward_loss: 0.04111, value_loss: 0.00705 action_loss: -5.33171
# update_step:  71 model loss: 37.20701, kl_loss: 4.33512, obs_loss: 32.82884, reward_loss: 0.04305, value_loss: 0.00298 action_loss: -5.33440
# update_step:  72 model loss: 30.52526, kl_loss: 4.21334, obs_loss: 26.26952, reward_loss: 0.04239, value_loss: 0.00318 action_loss: -5.30926
# update_step:  73 model loss: 35.08844, kl_loss: 4.25844, obs_loss: 30.78939, reward_loss: 0.04061, value_loss: 0.00648 action_loss: -5.27437
# update_step:  74 model loss: 35.74631, kl_loss: 4.50308, obs_loss: 31.20114, reward_loss: 0.04209, value_loss: 0.00847 action_loss: -5.29889
# update_step:  75 model loss: 31.81304, kl_loss: 4.29104, obs_loss: 27.48193, reward_loss: 0.04006, value_loss: 0.00510 action_loss: -5.34037
# update_step:  76 model loss: 33.48253, kl_loss: 4.34119, obs_loss: 29.09939, reward_loss: 0.04195, value_loss: 0.00472 action_loss: -5.31570
# update_step:  77 model loss: 30.07372, kl_loss: 4.12867, obs_loss: 25.90486, reward_loss: 0.04018, value_loss: 0.00279 action_loss: -5.35651
# update_step:  78 model loss: 32.60860, kl_loss: 4.29162, obs_loss: 28.27463, reward_loss: 0.04236, value_loss: 0.00288 action_loss: -5.40649
# update_step:  79 model loss: 33.74300, kl_loss: 4.28968, obs_loss: 29.41089, reward_loss: 0.04243, value_loss: 0.00198 action_loss: -5.39192
# update_step:  80 model loss: 34.03678, kl_loss: 4.56565, obs_loss: 29.43352, reward_loss: 0.03761, value_loss: 0.00272 action_loss: -5.34870
# update_step:  81 model loss: 29.72541, kl_loss: 3.88394, obs_loss: 25.79979, reward_loss: 0.04167, value_loss: 0.00240 action_loss: -5.27838
# update_step:  82 model loss: 31.23528, kl_loss: 4.07229, obs_loss: 27.12347, reward_loss: 0.03952, value_loss: 0.00264 action_loss: -5.26413
# update_step:  83 model loss: 31.07505, kl_loss: 4.14406, obs_loss: 26.88789, reward_loss: 0.04309, value_loss: 0.00391 action_loss: -5.25510
# update_step:  84 model loss: 28.89547, kl_loss: 4.27265, obs_loss: 24.58030, reward_loss: 0.04252, value_loss: 0.00421 action_loss: -5.22547
# update_step:  85 model loss: 30.38644, kl_loss: 4.32770, obs_loss: 26.01722, reward_loss: 0.04152, value_loss: 0.00483 action_loss: -5.20845
# update_step:  86 model loss: 30.52297, kl_loss: 4.23508, obs_loss: 26.24865, reward_loss: 0.03925, value_loss: 0.00260 action_loss: -5.17718
# update_step:  87 model loss: 28.72261, kl_loss: 4.05119, obs_loss: 24.62959, reward_loss: 0.04183, value_loss: 0.00211 action_loss: -5.13377
# update_step:  88 model loss: 31.72301, kl_loss: 4.14079, obs_loss: 27.54412, reward_loss: 0.03809, value_loss: 0.00283 action_loss: -5.27629
# update_step:  89 model loss: 31.96500, kl_loss: 4.24041, obs_loss: 27.68236, reward_loss: 0.04223, value_loss: 0.00396 action_loss: -5.21374
# update_step:  90 model loss: 32.37987, kl_loss: 4.17599, obs_loss: 28.16388, reward_loss: 0.04001, value_loss: 0.00716 action_loss: -5.21935
# update_step:  91 model loss: 31.22998, kl_loss: 4.32227, obs_loss: 26.86824, reward_loss: 0.03947, value_loss: 0.00998 action_loss: -5.15459
# update_step:  92 model loss: 31.70307, kl_loss: 4.35805, obs_loss: 27.30351, reward_loss: 0.04151, value_loss: 0.00892 action_loss: -5.19720
# update_step:  93 model loss: 27.62068, kl_loss: 4.16271, obs_loss: 23.41550, reward_loss: 0.04247, value_loss: 0.00577 action_loss: -5.28131
# update_step:  94 model loss: 29.71166, kl_loss: 4.12778, obs_loss: 25.54495, reward_loss: 0.03892, value_loss: 0.00339 action_loss: -5.33144
# update_step:  95 model loss: 36.20872, kl_loss: 4.79252, obs_loss: 31.37699, reward_loss: 0.03921, value_loss: 0.00207 action_loss: -5.25784
# update_step:  96 model loss: 31.77914, kl_loss: 4.48408, obs_loss: 27.25609, reward_loss: 0.03897, value_loss: 0.00217 action_loss: -5.29070
# update_step:  97 model loss: 31.67027, kl_loss: 4.23975, obs_loss: 27.38801, reward_loss: 0.04251, value_loss: 0.00464 action_loss: -5.22170
# update_step:  98 model loss: 28.57995, kl_loss: 4.14308, obs_loss: 24.39400, reward_loss: 0.04287, value_loss: 0.00547 action_loss: -5.28583
# update_step:  99 model loss: 28.19573, kl_loss: 4.15307, obs_loss: 23.99941, reward_loss: 0.04325, value_loss: 0.00637 action_loss: -5.26929
# update_step: 100 model loss: 33.54244, kl_loss: 4.41712, obs_loss: 29.08598, reward_loss: 0.03933, value_loss: 0.00455 action_loss: -5.33287
# elasped time for update: 94.61s
# episode [   2/  21] is collected. Total reward is 44.716394
# elasped time for interaction: 0.21s
# update_step:   1 model loss: 30.91030, kl_loss: 4.20568, obs_loss: 26.66415, reward_loss: 0.04046, value_loss: 0.00875 action_loss: -5.29341
# update_step:   2 model loss: 28.20847, kl_loss: 3.95086, obs_loss: 24.21447, reward_loss: 0.04314, value_loss: 0.00424 action_loss: -5.28258
# update_step:   3 model loss: 30.79162, kl_loss: 4.13749, obs_loss: 26.61216, reward_loss: 0.04197, value_loss: 0.00368 action_loss: -5.28910
# update_step:   4 model loss: 33.29327, kl_loss: 4.20318, obs_loss: 29.04724, reward_loss: 0.04285, value_loss: 0.00353 action_loss: -5.19430
# update_step:   5 model loss: 31.17838, kl_loss: 4.10745, obs_loss: 27.03045, reward_loss: 0.04047, value_loss: 0.00483 action_loss: -5.21031
# update_step:   6 model loss: 31.78882, kl_loss: 4.12172, obs_loss: 27.62536, reward_loss: 0.04174, value_loss: 0.00425 action_loss: -5.26020
# update_step:   7 model loss: 32.48494, kl_loss: 4.33464, obs_loss: 28.10684, reward_loss: 0.04346, value_loss: 0.00444 action_loss: -5.13479
# update_step:   8 model loss: 34.77032, kl_loss: 4.38943, obs_loss: 30.33888, reward_loss: 0.04200, value_loss: 0.00624 action_loss: -5.27113
# update_step:   9 model loss: 32.17200, kl_loss: 4.42454, obs_loss: 27.70812, reward_loss: 0.03934, value_loss: 0.00767 action_loss: -5.32821
# update_step:  10 model loss: 30.76189, kl_loss: 4.25144, obs_loss: 26.47136, reward_loss: 0.03909, value_loss: 0.00467 action_loss: -5.25020
# update_step:  11 model loss: 35.81596, kl_loss: 4.61614, obs_loss: 31.15982, reward_loss: 0.04000, value_loss: 0.00551 action_loss: -5.33272
# update_step:  12 model loss: 34.41224, kl_loss: 4.21079, obs_loss: 30.15933, reward_loss: 0.04211, value_loss: 0.00376 action_loss: -5.26260
# update_step:  13 model loss: 31.78500, kl_loss: 4.37705, obs_loss: 27.36859, reward_loss: 0.03936, value_loss: 0.00253 action_loss: -5.31818
# update_step:  14 model loss: 32.75558, kl_loss: 4.55155, obs_loss: 28.16333, reward_loss: 0.04071, value_loss: 0.00217 action_loss: -5.36588
# update_step:  15 model loss: 32.26287, kl_loss: 4.40814, obs_loss: 27.81414, reward_loss: 0.04058, value_loss: 0.00197 action_loss: -5.39985
# update_step:  16 model loss: 25.75732, kl_loss: 4.00968, obs_loss: 21.70734, reward_loss: 0.04030, value_loss: 0.00237 action_loss: -5.43064
# update_step:  17 model loss: 28.46088, kl_loss: 4.04780, obs_loss: 24.36787, reward_loss: 0.04520, value_loss: 0.00424 action_loss: -5.42179
# update_step:  18 model loss: 32.39576, kl_loss: 4.12686, obs_loss: 28.22939, reward_loss: 0.03951, value_loss: 0.00634 action_loss: -5.36910
# update_step:  19 model loss: 28.97799, kl_loss: 4.11106, obs_loss: 24.82584, reward_loss: 0.04109, value_loss: 0.00498 action_loss: -5.36782
# update_step:  20 model loss: 34.47432, kl_loss: 4.17667, obs_loss: 30.25690, reward_loss: 0.04075, value_loss: 0.00511 action_loss: -5.35180
# update_step:  21 model loss: 31.96786, kl_loss: 4.23979, obs_loss: 27.68780, reward_loss: 0.04026, value_loss: 0.00633 action_loss: -5.36512
# update_step:  22 model loss: 31.50409, kl_loss: 4.29459, obs_loss: 27.17023, reward_loss: 0.03928, value_loss: 0.00616 action_loss: -5.38423
# update_step:  23 model loss: 33.31393, kl_loss: 4.50852, obs_loss: 28.76595, reward_loss: 0.03945, value_loss: 0.00383 action_loss: -5.26574
# update_step:  24 model loss: 33.68802, kl_loss: 4.55287, obs_loss: 29.09436, reward_loss: 0.04079, value_loss: 0.00284 action_loss: -5.26477
# update_step:  25 model loss: 34.53405, kl_loss: 4.45691, obs_loss: 30.03536, reward_loss: 0.04178, value_loss: 0.00217 action_loss: -5.30048
# update_step:  26 model loss: 31.80288, kl_loss: 4.43629, obs_loss: 27.32524, reward_loss: 0.04135, value_loss: 0.00209 action_loss: -5.29980
# update_step:  27 model loss: 30.60849, kl_loss: 4.08548, obs_loss: 26.48382, reward_loss: 0.03919, value_loss: 0.00373 action_loss: -5.19861
# update_step:  28 model loss: 27.68327, kl_loss: 4.01997, obs_loss: 23.62278, reward_loss: 0.04052, value_loss: 0.00259 action_loss: -5.19490
# update_step:  29 model loss: 29.16181, kl_loss: 4.11231, obs_loss: 25.00924, reward_loss: 0.04027, value_loss: 0.00314 action_loss: -5.14325
# update_step:  30 model loss: 27.05769, kl_loss: 4.10014, obs_loss: 22.91752, reward_loss: 0.04004, value_loss: 0.00291 action_loss: -5.16778
# update_step:  31 model loss: 33.58802, kl_loss: 4.45345, obs_loss: 29.09443, reward_loss: 0.04014, value_loss: 0.00356 action_loss: -5.12494
# update_step:  32 model loss: 32.23442, kl_loss: 4.55189, obs_loss: 27.63936, reward_loss: 0.04317, value_loss: 0.00395 action_loss: -5.06534
# update_step:  33 model loss: 28.32303, kl_loss: 4.11917, obs_loss: 24.16389, reward_loss: 0.03997, value_loss: 0.00157 action_loss: -5.18987
# update_step:  34 model loss: 31.73103, kl_loss: 4.74072, obs_loss: 26.95120, reward_loss: 0.03911, value_loss: 0.00303 action_loss: -5.08571
# update_step:  35 model loss: 31.35746, kl_loss: 4.62680, obs_loss: 26.68939, reward_loss: 0.04126, value_loss: 0.00254 action_loss: -5.16613
# update_step:  36 model loss: 31.00681, kl_loss: 4.26012, obs_loss: 26.70505, reward_loss: 0.04163, value_loss: 0.00237 action_loss: -5.12261
# update_step:  37 model loss: 31.85130, kl_loss: 4.17804, obs_loss: 27.63160, reward_loss: 0.04166, value_loss: 0.00323 action_loss: -5.15037
# update_step:  38 model loss: 31.80498, kl_loss: 4.31185, obs_loss: 27.45208, reward_loss: 0.04105, value_loss: 0.00333 action_loss: -5.07203
# update_step:  39 model loss: 32.22314, kl_loss: 4.15862, obs_loss: 28.02275, reward_loss: 0.04177, value_loss: 0.00271 action_loss: -5.11547
# update_step:  40 model loss: 33.78946, kl_loss: 4.29562, obs_loss: 29.45065, reward_loss: 0.04320, value_loss: 0.00344 action_loss: -5.09606
# update_step:  41 model loss: 28.31678, kl_loss: 4.26444, obs_loss: 24.01182, reward_loss: 0.04052, value_loss: 0.00386 action_loss: -5.08361
# update_step:  42 model loss: 30.82905, kl_loss: 4.35766, obs_loss: 26.43005, reward_loss: 0.04133, value_loss: 0.00611 action_loss: -5.10680
# update_step:  43 model loss: 31.03677, kl_loss: 4.14625, obs_loss: 26.84947, reward_loss: 0.04104, value_loss: 0.00957 action_loss: -5.15737
# update_step:  44 model loss: 30.39081, kl_loss: 4.57037, obs_loss: 25.78195, reward_loss: 0.03849, value_loss: 0.00904 action_loss: -5.22348
# update_step:  45 model loss: 26.63815, kl_loss: 4.44275, obs_loss: 22.15529, reward_loss: 0.04010, value_loss: 0.00767 action_loss: -5.28000
# update_step:  46 model loss: 33.16544, kl_loss: 4.59500, obs_loss: 28.52840, reward_loss: 0.04203, value_loss: 0.00530 action_loss: -5.28132
# update_step:  47 model loss: 29.25045, kl_loss: 4.53518, obs_loss: 24.67351, reward_loss: 0.04177, value_loss: 0.00251 action_loss: -5.30076
# update_step:  48 model loss: 29.92703, kl_loss: 4.56940, obs_loss: 25.31465, reward_loss: 0.04298, value_loss: 0.00162 action_loss: -5.36452
# update_step:  49 model loss: 32.23844, kl_loss: 4.17250, obs_loss: 28.02389, reward_loss: 0.04205, value_loss: 0.00269 action_loss: -5.37803
# update_step:  50 model loss: 29.18369, kl_loss: 4.30546, obs_loss: 24.83664, reward_loss: 0.04158, value_loss: 0.00470 action_loss: -5.32669
# update_step:  51 model loss: 28.21846, kl_loss: 4.38022, obs_loss: 23.79801, reward_loss: 0.04024, value_loss: 0.00614 action_loss: -5.34170
# update_step:  52 model loss: 32.62470, kl_loss: 4.47423, obs_loss: 28.10812, reward_loss: 0.04235, value_loss: 0.00654 action_loss: -5.37205
# update_step:  53 model loss: 28.60154, kl_loss: 4.24070, obs_loss: 24.32382, reward_loss: 0.03702, value_loss: 0.00549 action_loss: -5.35930
# update_step:  54 model loss: 32.81833, kl_loss: 4.18691, obs_loss: 28.59238, reward_loss: 0.03905, value_loss: 0.00466 action_loss: -5.39511
# update_step:  55 model loss: 30.93020, kl_loss: 4.53272, obs_loss: 26.35549, reward_loss: 0.04200, value_loss: 0.00310 action_loss: -5.33554
# update_step:  56 model loss: 28.95009, kl_loss: 4.34905, obs_loss: 24.55844, reward_loss: 0.04260, value_loss: 0.00330 action_loss: -5.34377
# update_step:  57 model loss: 29.13668, kl_loss: 4.24468, obs_loss: 24.84843, reward_loss: 0.04357, value_loss: 0.00365 action_loss: -5.37083
# update_step:  58 model loss: 28.01386, kl_loss: 4.01642, obs_loss: 23.95719, reward_loss: 0.04025, value_loss: 0.00365 action_loss: -5.36323
# update_step:  59 model loss: 26.58688, kl_loss: 4.16167, obs_loss: 22.38506, reward_loss: 0.04014, value_loss: 0.00290 action_loss: -5.32805
# update_step:  60 model loss: 31.45609, kl_loss: 4.34667, obs_loss: 27.06658, reward_loss: 0.04283, value_loss: 0.00197 action_loss: -5.26877
# update_step:  61 model loss: 27.40154, kl_loss: 4.27064, obs_loss: 23.08868, reward_loss: 0.04222, value_loss: 0.00317 action_loss: -5.31745
# update_step:  62 model loss: 29.01369, kl_loss: 4.24043, obs_loss: 24.73380, reward_loss: 0.03945, value_loss: 0.00341 action_loss: -5.27020
# update_step:  63 model loss: 27.76244, kl_loss: 4.04357, obs_loss: 23.67766, reward_loss: 0.04121, value_loss: 0.00488 action_loss: -5.25088
# update_step:  64 model loss: 33.62473, kl_loss: 4.41252, obs_loss: 29.17176, reward_loss: 0.04044, value_loss: 0.00573 action_loss: -5.14483
# update_step:  65 model loss: 27.82328, kl_loss: 4.19145, obs_loss: 23.58927, reward_loss: 0.04256, value_loss: 0.00445 action_loss: -5.20226
# update_step:  66 model loss: 30.45768, kl_loss: 4.39855, obs_loss: 26.01674, reward_loss: 0.04238, value_loss: 0.00370 action_loss: -5.19160
# update_step:  67 model loss: 27.60334, kl_loss: 4.17121, obs_loss: 23.39168, reward_loss: 0.04045, value_loss: 0.00383 action_loss: -5.11376
# update_step:  68 model loss: 31.93417, kl_loss: 4.32583, obs_loss: 27.56817, reward_loss: 0.04016, value_loss: 0.00223 action_loss: -5.13773
# update_step:  69 model loss: 27.61425, kl_loss: 4.23952, obs_loss: 23.33512, reward_loss: 0.03961, value_loss: 0.00420 action_loss: -5.17507
# update_step:  70 model loss: 30.40916, kl_loss: 4.31315, obs_loss: 26.05503, reward_loss: 0.04098, value_loss: 0.00607 action_loss: -5.12323
# update_step:  71 model loss: 31.02023, kl_loss: 4.43571, obs_loss: 26.54392, reward_loss: 0.04061, value_loss: 0.01489 action_loss: -5.13833
# update_step:  72 model loss: 27.76386, kl_loss: 4.39697, obs_loss: 23.32506, reward_loss: 0.04184, value_loss: 0.01646 action_loss: -5.16251
# update_step:  73 model loss: 31.76270, kl_loss: 4.67552, obs_loss: 27.04690, reward_loss: 0.04028, value_loss: 0.02401 action_loss: -5.17625
# update_step:  74 model loss: 29.08073, kl_loss: 4.88385, obs_loss: 24.15717, reward_loss: 0.03971, value_loss: 0.02390 action_loss: -5.28129
# update_step:  75 model loss: 31.19530, kl_loss: 4.40540, obs_loss: 26.75181, reward_loss: 0.03809, value_loss: 0.02002 action_loss: -5.37810
# update_step:  76 model loss: 27.86702, kl_loss: 3.99702, obs_loss: 23.82720, reward_loss: 0.04280, value_loss: 0.00828 action_loss: -5.40866
# update_step:  77 model loss: 27.27759, kl_loss: 4.35992, obs_loss: 22.87645, reward_loss: 0.04122, value_loss: 0.00734 action_loss: -5.42106
# update_step:  78 model loss: 25.81134, kl_loss: 4.11996, obs_loss: 21.65407, reward_loss: 0.03731, value_loss: 0.00506 action_loss: -5.45065
# update_step:  79 model loss: 28.13973, kl_loss: 4.11801, obs_loss: 23.98055, reward_loss: 0.04118, value_loss: 0.00858 action_loss: -5.46130
# update_step:  80 model loss: 27.13512, kl_loss: 4.15880, obs_loss: 22.93533, reward_loss: 0.04099, value_loss: 0.01614 action_loss: -5.50241
# update_step:  81 model loss: 26.51720, kl_loss: 4.10019, obs_loss: 22.37608, reward_loss: 0.04093, value_loss: 0.01568 action_loss: -5.52543
# update_step:  82 model loss: 29.42741, kl_loss: 4.34831, obs_loss: 25.03734, reward_loss: 0.04176, value_loss: 0.01903 action_loss: -5.51662
# update_step:  83 model loss: 29.49751, kl_loss: 4.47627, obs_loss: 24.98046, reward_loss: 0.04078, value_loss: 0.01459 action_loss: -5.48279
# update_step:  84 model loss: 26.60518, kl_loss: 4.41464, obs_loss: 22.14941, reward_loss: 0.04113, value_loss: 0.01024 action_loss: -5.48831
# update_step:  85 model loss: 24.98412, kl_loss: 4.05433, obs_loss: 20.88635, reward_loss: 0.04344, value_loss: 0.00275 action_loss: -5.57636
# update_step:  86 model loss: 30.90484, kl_loss: 4.21728, obs_loss: 26.64570, reward_loss: 0.04186, value_loss: 0.00358 action_loss: -5.49586
# update_step:  87 model loss: 27.85028, kl_loss: 4.12465, obs_loss: 23.68563, reward_loss: 0.04000, value_loss: 0.00739 action_loss: -5.43894
# update_step:  88 model loss: 28.25294, kl_loss: 4.61923, obs_loss: 23.59461, reward_loss: 0.03910, value_loss: 0.01567 action_loss: -5.47740
# update_step:  89 model loss: 29.74841, kl_loss: 4.56885, obs_loss: 25.13797, reward_loss: 0.04159, value_loss: 0.02011 action_loss: -5.46733
# update_step:  90 model loss: 30.45869, kl_loss: 4.48403, obs_loss: 25.93382, reward_loss: 0.04084, value_loss: 0.01225 action_loss: -5.53341
# update_step:  91 model loss: 25.77260, kl_loss: 4.21801, obs_loss: 21.51341, reward_loss: 0.04117, value_loss: 0.00540 action_loss: -5.45901
# update_step:  92 model loss: 28.38030, kl_loss: 4.00839, obs_loss: 24.32939, reward_loss: 0.04252, value_loss: 0.00308 action_loss: -5.41115
# update_step:  93 model loss: 26.70358, kl_loss: 3.97751, obs_loss: 22.68448, reward_loss: 0.04160, value_loss: 0.01138 action_loss: -5.35323
# update_step:  94 model loss: 30.21512, kl_loss: 4.36294, obs_loss: 25.81283, reward_loss: 0.03936, value_loss: 0.02406 action_loss: -5.28127
# update_step:  95 model loss: 27.66628, kl_loss: 4.11819, obs_loss: 23.50899, reward_loss: 0.03910, value_loss: 0.03215 action_loss: -5.22509
# update_step:  96 model loss: 29.95815, kl_loss: 4.24975, obs_loss: 25.66592, reward_loss: 0.04248, value_loss: 0.02458 action_loss: -5.18819
# update_step:  97 model loss: 28.45992, kl_loss: 3.99541, obs_loss: 24.42397, reward_loss: 0.04055, value_loss: 0.01667 action_loss: -5.12829
# update_step:  98 model loss: 31.96095, kl_loss: 4.38588, obs_loss: 27.53295, reward_loss: 0.04212, value_loss: 0.00533 action_loss: -5.12671
# update_step:  99 model loss: 26.49078, kl_loss: 4.16077, obs_loss: 22.28766, reward_loss: 0.04235, value_loss: 0.00408 action_loss: -5.14742
# update_step: 100 model loss: 27.15257, kl_loss: 4.43088, obs_loss: 22.68402, reward_loss: 0.03767, value_loss: 0.01068 action_loss: -5.17735
# elasped time for update: 93.05s
# episode [   3/  21] is collected. Total reward is 48.678659
# elasped time for interaction: 0.20s
# update_step:   1 model loss: 29.67750, kl_loss: 4.44177, obs_loss: 25.19525, reward_loss: 0.04047, value_loss: 0.02285 action_loss: -5.21828
# update_step:   2 model loss: 24.44948, kl_loss: 4.07752, obs_loss: 20.33188, reward_loss: 0.04007, value_loss: 0.02379 action_loss: -5.21092
# update_step:   3 model loss: 27.54679, kl_loss: 4.22221, obs_loss: 23.28486, reward_loss: 0.03972, value_loss: 0.01698 action_loss: -5.26503
# update_step:   4 model loss: 30.11189, kl_loss: 4.30145, obs_loss: 25.77054, reward_loss: 0.03991, value_loss: 0.01199 action_loss: -5.26124
# update_step:   5 model loss: 32.30505, kl_loss: 4.42594, obs_loss: 27.84062, reward_loss: 0.03848, value_loss: 0.00653 action_loss: -5.20508
# update_step:   6 model loss: 25.38497, kl_loss: 4.24073, obs_loss: 21.10399, reward_loss: 0.04025, value_loss: 0.00368 action_loss: -5.19561
# update_step:   7 model loss: 27.86038, kl_loss: 4.21634, obs_loss: 23.60244, reward_loss: 0.04159, value_loss: 0.00342 action_loss: -5.16846
# update_step:   8 model loss: 28.29143, kl_loss: 4.20763, obs_loss: 24.04364, reward_loss: 0.04016, value_loss: 0.00522 action_loss: -5.13398
# update_step:   9 model loss: 28.83795, kl_loss: 4.06931, obs_loss: 24.72732, reward_loss: 0.04132, value_loss: 0.00864 action_loss: -5.23008
# update_step:  10 model loss: 30.52750, kl_loss: 4.42292, obs_loss: 26.06277, reward_loss: 0.04180, value_loss: 0.00813 action_loss: -5.11795
# update_step:  11 model loss: 31.27098, kl_loss: 4.23198, obs_loss: 26.99594, reward_loss: 0.04307, value_loss: 0.00984 action_loss: -5.10398
# update_step:  12 model loss: 28.92476, kl_loss: 4.01992, obs_loss: 24.86364, reward_loss: 0.04120, value_loss: 0.00520 action_loss: -5.14816
# update_step:  13 model loss: 25.83006, kl_loss: 4.38676, obs_loss: 21.40159, reward_loss: 0.04172, value_loss: 0.00275 action_loss: -5.17440
# update_step:  14 model loss: 28.41714, kl_loss: 4.27035, obs_loss: 24.10845, reward_loss: 0.03833, value_loss: 0.00242 action_loss: -5.25932
# update_step:  15 model loss: 28.25079, kl_loss: 4.45486, obs_loss: 23.75319, reward_loss: 0.04275, value_loss: 0.00439 action_loss: -5.24216
# update_step:  16 model loss: 31.25931, kl_loss: 4.47723, obs_loss: 26.74058, reward_loss: 0.04150, value_loss: 0.00916 action_loss: -5.30821
# update_step:  17 model loss: 26.09180, kl_loss: 4.27101, obs_loss: 21.77963, reward_loss: 0.04116, value_loss: 0.01441 action_loss: -5.31751
# update_step:  18 model loss: 28.53737, kl_loss: 4.38799, obs_loss: 24.10963, reward_loss: 0.03975, value_loss: 0.01442 action_loss: -5.32938
# update_step:  19 model loss: 25.41438, kl_loss: 4.05315, obs_loss: 21.32006, reward_loss: 0.04116, value_loss: 0.01610 action_loss: -5.36657
# update_step:  20 model loss: 28.68937, kl_loss: 4.12451, obs_loss: 24.52200, reward_loss: 0.04287, value_loss: 0.00772 action_loss: -5.36315
# update_step:  21 model loss: 29.59857, kl_loss: 4.36312, obs_loss: 25.19470, reward_loss: 0.04075, value_loss: 0.00387 action_loss: -5.41611
# update_step:  22 model loss: 26.72114, kl_loss: 4.35925, obs_loss: 22.32182, reward_loss: 0.04007, value_loss: 0.00619 action_loss: -5.31350
# update_step:  23 model loss: 27.40013, kl_loss: 4.29448, obs_loss: 23.06384, reward_loss: 0.04181, value_loss: 0.01293 action_loss: -5.33958
# update_step:  24 model loss: 28.05009, kl_loss: 4.21028, obs_loss: 23.79772, reward_loss: 0.04210, value_loss: 0.01611 action_loss: -5.29783
# update_step:  25 model loss: 25.83914, kl_loss: 4.19877, obs_loss: 21.59888, reward_loss: 0.04149, value_loss: 0.01034 action_loss: -5.32491
# update_step:  26 model loss: 25.70174, kl_loss: 4.28600, obs_loss: 21.37358, reward_loss: 0.04216, value_loss: 0.00876 action_loss: -5.32472
# update_step:  27 model loss: 27.81706, kl_loss: 4.15280, obs_loss: 23.62148, reward_loss: 0.04278, value_loss: 0.00559 action_loss: -5.34931
# update_step:  28 model loss: 25.43881, kl_loss: 4.16174, obs_loss: 21.23641, reward_loss: 0.04066, value_loss: 0.00470 action_loss: -5.37788
# update_step:  29 model loss: 27.43065, kl_loss: 4.47875, obs_loss: 22.91024, reward_loss: 0.04166, value_loss: 0.00670 action_loss: -5.37373
# update_step:  30 model loss: 27.96548, kl_loss: 4.23877, obs_loss: 23.68655, reward_loss: 0.04016, value_loss: 0.00806 action_loss: -5.35798
# update_step:  31 model loss: 24.84081, kl_loss: 4.18837, obs_loss: 20.61144, reward_loss: 0.04100, value_loss: 0.00874 action_loss: -5.37395
# update_step:  32 model loss: 27.72485, kl_loss: 4.37065, obs_loss: 23.31504, reward_loss: 0.03917, value_loss: 0.00968 action_loss: -5.38587
# update_step:  33 model loss: 29.62837, kl_loss: 4.31043, obs_loss: 25.27582, reward_loss: 0.04212, value_loss: 0.00529 action_loss: -5.37556
# update_step:  34 model loss: 26.64008, kl_loss: 4.14671, obs_loss: 22.45278, reward_loss: 0.04059, value_loss: 0.00307 action_loss: -5.35702
# update_step:  35 model loss: 27.05892, kl_loss: 4.14945, obs_loss: 22.86743, reward_loss: 0.04204, value_loss: 0.00383 action_loss: -5.38113
# update_step:  36 model loss: 27.43659, kl_loss: 4.18858, obs_loss: 23.20957, reward_loss: 0.03845, value_loss: 0.00645 action_loss: -5.40364
# update_step:  37 model loss: 26.81174, kl_loss: 4.37554, obs_loss: 22.39588, reward_loss: 0.04032, value_loss: 0.01100 action_loss: -5.36613
# update_step:  38 model loss: 29.23573, kl_loss: 4.66825, obs_loss: 24.52638, reward_loss: 0.04110, value_loss: 0.01739 action_loss: -5.30917
# update_step:  39 model loss: 28.52772, kl_loss: 4.35893, obs_loss: 24.12881, reward_loss: 0.03998, value_loss: 0.01606 action_loss: -5.29026
# update_step:  40 model loss: 27.86042, kl_loss: 4.35663, obs_loss: 23.46445, reward_loss: 0.03934, value_loss: 0.01492 action_loss: -5.18222
# update_step:  41 model loss: 27.02020, kl_loss: 4.46263, obs_loss: 22.51513, reward_loss: 0.04243, value_loss: 0.00846 action_loss: -5.19834
# update_step:  42 model loss: 29.04471, kl_loss: 4.16767, obs_loss: 24.83831, reward_loss: 0.03874, value_loss: 0.00495 action_loss: -5.17089
# update_step:  43 model loss: 26.59498, kl_loss: 4.11089, obs_loss: 22.44164, reward_loss: 0.04246, value_loss: 0.00397 action_loss: -5.13306
# update_step:  44 model loss: 24.97041, kl_loss: 4.08935, obs_loss: 20.83824, reward_loss: 0.04283, value_loss: 0.00571 action_loss: -5.15153
# update_step:  45 model loss: 31.37915, kl_loss: 4.67897, obs_loss: 26.65961, reward_loss: 0.04056, value_loss: 0.01512 action_loss: -5.21042
# update_step:  46 model loss: 23.87308, kl_loss: 4.14213, obs_loss: 19.68923, reward_loss: 0.04172, value_loss: 0.01914 action_loss: -5.24599
# update_step:  47 model loss: 30.34366, kl_loss: 4.39730, obs_loss: 25.90683, reward_loss: 0.03953, value_loss: 0.02215 action_loss: -5.22482
# update_step:  48 model loss: 25.22140, kl_loss: 4.20836, obs_loss: 20.97205, reward_loss: 0.04099, value_loss: 0.02041 action_loss: -5.21892
# update_step:  49 model loss: 27.83557, kl_loss: 4.69921, obs_loss: 23.09938, reward_loss: 0.03698, value_loss: 0.01915 action_loss: -5.21708
# update_step:  50 model loss: 27.89082, kl_loss: 4.30503, obs_loss: 23.54543, reward_loss: 0.04036, value_loss: 0.01364 action_loss: -5.31148
# update_step:  51 model loss: 24.73910, kl_loss: 4.17414, obs_loss: 20.52401, reward_loss: 0.04095, value_loss: 0.00644 action_loss: -5.34002
# update_step:  52 model loss: 29.99517, kl_loss: 4.49924, obs_loss: 25.45440, reward_loss: 0.04153, value_loss: 0.00490 action_loss: -5.34537
# update_step:  53 model loss: 25.35399, kl_loss: 4.09924, obs_loss: 21.21381, reward_loss: 0.04095, value_loss: 0.00636 action_loss: -5.33026
# update_step:  54 model loss: 29.85409, kl_loss: 4.34969, obs_loss: 25.46342, reward_loss: 0.04098, value_loss: 0.01431 action_loss: -5.33916
# update_step:  55 model loss: 24.26170, kl_loss: 4.01417, obs_loss: 20.20884, reward_loss: 0.03870, value_loss: 0.01974 action_loss: -5.33802
# update_step:  56 model loss: 28.17727, kl_loss: 4.37736, obs_loss: 23.76072, reward_loss: 0.03918, value_loss: 0.01875 action_loss: -5.38134
# update_step:  57 model loss: 26.46143, kl_loss: 4.34947, obs_loss: 22.07273, reward_loss: 0.03923, value_loss: 0.01913 action_loss: -5.40345
# update_step:  58 model loss: 30.72492, kl_loss: 4.50210, obs_loss: 26.18104, reward_loss: 0.04179, value_loss: 0.00991 action_loss: -5.38117
# update_step:  59 model loss: 26.45220, kl_loss: 4.31146, obs_loss: 22.10119, reward_loss: 0.03955, value_loss: 0.00524 action_loss: -5.39382
# update_step:  60 model loss: 29.77346, kl_loss: 4.26977, obs_loss: 25.46340, reward_loss: 0.04029, value_loss: 0.00399 action_loss: -5.40274
# update_step:  61 model loss: 26.32201, kl_loss: 4.23528, obs_loss: 22.04477, reward_loss: 0.04195, value_loss: 0.00324 action_loss: -5.34455
# update_step:  62 model loss: 27.00022, kl_loss: 4.19672, obs_loss: 22.76036, reward_loss: 0.04314, value_loss: 0.00294 action_loss: -5.27824
# update_step:  63 model loss: 26.69757, kl_loss: 4.17137, obs_loss: 22.48406, reward_loss: 0.04214, value_loss: 0.00310 action_loss: -5.24398
# update_step:  64 model loss: 26.98513, kl_loss: 4.14743, obs_loss: 22.79671, reward_loss: 0.04100, value_loss: 0.00336 action_loss: -5.19767
# update_step:  65 model loss: 28.82564, kl_loss: 4.51666, obs_loss: 24.26759, reward_loss: 0.04139, value_loss: 0.00317 action_loss: -5.15794
# update_step:  66 model loss: 27.15904, kl_loss: 4.31394, obs_loss: 22.80407, reward_loss: 0.04103, value_loss: 0.00284 action_loss: -5.17240
# update_step:  67 model loss: 28.56896, kl_loss: 4.35952, obs_loss: 24.16873, reward_loss: 0.04072, value_loss: 0.00299 action_loss: -5.17043
# update_step:  68 model loss: 27.72849, kl_loss: 4.20941, obs_loss: 23.47697, reward_loss: 0.04212, value_loss: 0.00321 action_loss: -5.09724
# update_step:  69 model loss: 27.91302, kl_loss: 4.23866, obs_loss: 23.63229, reward_loss: 0.04206, value_loss: 0.00259 action_loss: -5.11450
# update_step:  70 model loss: 26.76548, kl_loss: 4.46860, obs_loss: 22.25649, reward_loss: 0.04039, value_loss: 0.00310 action_loss: -5.05740
# update_step:  71 model loss: 25.58513, kl_loss: 4.32593, obs_loss: 21.21775, reward_loss: 0.04145, value_loss: 0.00267 action_loss: -5.06370
# update_step:  72 model loss: 27.24431, kl_loss: 4.31186, obs_loss: 22.89088, reward_loss: 0.04157, value_loss: 0.00367 action_loss: -5.06972
# update_step:  73 model loss: 25.64709, kl_loss: 4.35073, obs_loss: 21.25526, reward_loss: 0.04110, value_loss: 0.00483 action_loss: -5.04387
# update_step:  74 model loss: 26.39750, kl_loss: 4.17575, obs_loss: 22.17903, reward_loss: 0.04273, value_loss: 0.00712 action_loss: -5.09770
# update_step:  75 model loss: 24.85221, kl_loss: 4.10101, obs_loss: 20.71297, reward_loss: 0.03823, value_loss: 0.01353 action_loss: -5.22772
# update_step:  76 model loss: 29.12973, kl_loss: 4.40931, obs_loss: 24.68198, reward_loss: 0.03844, value_loss: 0.01204 action_loss: -5.19555
# update_step:  77 model loss: 24.78759, kl_loss: 3.93977, obs_loss: 20.80599, reward_loss: 0.04184, value_loss: 0.00759 action_loss: -5.16029
# update_step:  78 model loss: 25.96822, kl_loss: 4.25137, obs_loss: 21.67423, reward_loss: 0.04262, value_loss: 0.00368 action_loss: -5.11965
# update_step:  79 model loss: 25.51400, kl_loss: 4.24948, obs_loss: 21.22454, reward_loss: 0.03998, value_loss: 0.00494 action_loss: -5.19663
# update_step:  80 model loss: 28.39648, kl_loss: 4.42845, obs_loss: 23.92812, reward_loss: 0.03990, value_loss: 0.00524 action_loss: -5.13585
# update_step:  81 model loss: 26.79730, kl_loss: 4.29229, obs_loss: 22.46794, reward_loss: 0.03707, value_loss: 0.00418 action_loss: -5.20124
# update_step:  82 model loss: 27.80401, kl_loss: 4.31572, obs_loss: 23.44881, reward_loss: 0.03948, value_loss: 0.00645 action_loss: -5.22899
# update_step:  83 model loss: 27.98676, kl_loss: 4.30027, obs_loss: 23.64699, reward_loss: 0.03951, value_loss: 0.00647 action_loss: -5.22875
# update_step:  84 model loss: 27.87059, kl_loss: 4.41253, obs_loss: 23.41865, reward_loss: 0.03942, value_loss: 0.00828 action_loss: -5.22274
# update_step:  85 model loss: 24.24542, kl_loss: 4.41795, obs_loss: 19.78648, reward_loss: 0.04099, value_loss: 0.00455 action_loss: -5.26643
# update_step:  86 model loss: 27.87004, kl_loss: 4.23857, obs_loss: 23.58943, reward_loss: 0.04203, value_loss: 0.00691 action_loss: -5.13793
# update_step:  87 model loss: 28.91465, kl_loss: 4.13464, obs_loss: 24.73726, reward_loss: 0.04275, value_loss: 0.00415 action_loss: -5.17195
# update_step:  88 model loss: 30.44084, kl_loss: 4.30545, obs_loss: 26.09536, reward_loss: 0.04003, value_loss: 0.00419 action_loss: -5.22019
# update_step:  89 model loss: 29.60637, kl_loss: 4.55470, obs_loss: 25.01464, reward_loss: 0.03702, value_loss: 0.00599 action_loss: -5.17946
# update_step:  90 model loss: 27.96519, kl_loss: 4.31018, obs_loss: 23.61329, reward_loss: 0.04172, value_loss: 0.00567 action_loss: -5.16620
# update_step:  91 model loss: 27.98835, kl_loss: 4.51548, obs_loss: 23.42926, reward_loss: 0.04361, value_loss: 0.00802 action_loss: -5.15533
# update_step:  92 model loss: 24.87385, kl_loss: 4.27543, obs_loss: 20.55659, reward_loss: 0.04183, value_loss: 0.00504 action_loss: -5.18395
# update_step:  93 model loss: 29.94897, kl_loss: 4.67437, obs_loss: 25.23182, reward_loss: 0.04278, value_loss: 0.00603 action_loss: -5.20139
# update_step:  94 model loss: 25.93598, kl_loss: 4.25190, obs_loss: 21.64289, reward_loss: 0.04119, value_loss: 0.00424 action_loss: -5.28217
# update_step:  95 model loss: 27.01516, kl_loss: 4.22311, obs_loss: 22.74988, reward_loss: 0.04218, value_loss: 0.00251 action_loss: -5.28940
# update_step:  96 model loss: 29.63166, kl_loss: 4.08044, obs_loss: 25.50846, reward_loss: 0.04276, value_loss: 0.00300 action_loss: -5.23876
# update_step:  97 model loss: 27.62843, kl_loss: 4.24875, obs_loss: 23.33902, reward_loss: 0.04066, value_loss: 0.00508 action_loss: -5.25084
# update_step:  98 model loss: 30.21860, kl_loss: 4.44419, obs_loss: 25.73517, reward_loss: 0.03924, value_loss: 0.00571 action_loss: -5.23191
# update_step:  99 model loss: 30.69792, kl_loss: 4.55808, obs_loss: 26.10048, reward_loss: 0.03936, value_loss: 0.00571 action_loss: -5.14719
# update_step: 100 model loss: 25.74633, kl_loss: 4.06285, obs_loss: 21.64221, reward_loss: 0.04128, value_loss: 0.00426 action_loss: -5.23865
# elasped time for update: 90.64s
# episode [   4/  21] is collected. Total reward is 55.655432
# elasped time for interaction: 0.32s
# update_step:   1 model loss: 30.55850, kl_loss: 4.05533, obs_loss: 26.46401, reward_loss: 0.03916, value_loss: 0.00569 action_loss: -5.27014
# update_step:   2 model loss: 31.14745, kl_loss: 4.57555, obs_loss: 26.53168, reward_loss: 0.04022, value_loss: 0.00442 action_loss: -5.31007
# update_step:   3 model loss: 28.58188, kl_loss: 4.26203, obs_loss: 24.27390, reward_loss: 0.04596, value_loss: 0.00450 action_loss: -5.28017
# update_step:   4 model loss: 27.37121, kl_loss: 4.27533, obs_loss: 23.05923, reward_loss: 0.03665, value_loss: 0.00429 action_loss: -5.28745
# update_step:   5 model loss: 27.58395, kl_loss: 4.33565, obs_loss: 23.20694, reward_loss: 0.04136, value_loss: 0.00423 action_loss: -5.22492
# update_step:   6 model loss: 31.85635, kl_loss: 4.52539, obs_loss: 27.29108, reward_loss: 0.03988, value_loss: 0.00404 action_loss: -5.29690
# update_step:   7 model loss: 29.53500, kl_loss: 4.40438, obs_loss: 25.09004, reward_loss: 0.04058, value_loss: 0.00346 action_loss: -5.35349
# update_step:   8 model loss: 26.41644, kl_loss: 4.18587, obs_loss: 22.19043, reward_loss: 0.04014, value_loss: 0.00330 action_loss: -5.36117
# update_step:   9 model loss: 27.85695, kl_loss: 4.17728, obs_loss: 23.63829, reward_loss: 0.04138, value_loss: 0.00609 action_loss: -5.31765
# update_step:  10 model loss: 29.22788, kl_loss: 4.34584, obs_loss: 24.84031, reward_loss: 0.04173, value_loss: 0.00720 action_loss: -5.27479
# update_step:  11 model loss: 29.76108, kl_loss: 4.36255, obs_loss: 25.35765, reward_loss: 0.04087, value_loss: 0.00698 action_loss: -5.19384
# update_step:  12 model loss: 26.50709, kl_loss: 4.31713, obs_loss: 22.14718, reward_loss: 0.04278, value_loss: 0.00545 action_loss: -5.20691
# update_step:  13 model loss: 25.84178, kl_loss: 4.08671, obs_loss: 21.71276, reward_loss: 0.04231, value_loss: 0.00472 action_loss: -5.18124
# update_step:  14 model loss: 29.61766, kl_loss: 4.46759, obs_loss: 25.11188, reward_loss: 0.03819, value_loss: 0.00336 action_loss: -5.17220
# update_step:  15 model loss: 30.58166, kl_loss: 4.25643, obs_loss: 26.28624, reward_loss: 0.03899, value_loss: 0.00287 action_loss: -5.15309
# update_step:  16 model loss: 27.94411, kl_loss: 4.66909, obs_loss: 23.23410, reward_loss: 0.04092, value_loss: 0.00554 action_loss: -5.08657
# update_step:  17 model loss: 27.16245, kl_loss: 4.20932, obs_loss: 22.91294, reward_loss: 0.04019, value_loss: 0.00539 action_loss: -5.18276
# update_step:  18 model loss: 27.90845, kl_loss: 4.17693, obs_loss: 23.69286, reward_loss: 0.03867, value_loss: 0.00813 action_loss: -5.24686
# update_step:  19 model loss: 28.19308, kl_loss: 4.18386, obs_loss: 23.96893, reward_loss: 0.04029, value_loss: 0.00674 action_loss: -5.24556
# update_step:  20 model loss: 28.41809, kl_loss: 4.37354, obs_loss: 24.00296, reward_loss: 0.04160, value_loss: 0.00947 action_loss: -5.25959
# update_step:  21 model loss: 27.04272, kl_loss: 4.26644, obs_loss: 22.73575, reward_loss: 0.04052, value_loss: 0.00698 action_loss: -5.18121
# update_step:  22 model loss: 23.73716, kl_loss: 4.17543, obs_loss: 19.52139, reward_loss: 0.04035, value_loss: 0.00747 action_loss: -5.23918
# update_step:  23 model loss: 30.71877, kl_loss: 4.40550, obs_loss: 26.27300, reward_loss: 0.04027, value_loss: 0.00716 action_loss: -5.26497
# update_step:  24 model loss: 27.11362, kl_loss: 4.30352, obs_loss: 22.76979, reward_loss: 0.04031, value_loss: 0.00551 action_loss: -5.35254
# update_step:  25 model loss: 28.75655, kl_loss: 4.45634, obs_loss: 24.26220, reward_loss: 0.03801, value_loss: 0.00483 action_loss: -5.38539
# update_step:  26 model loss: 29.15616, kl_loss: 4.35349, obs_loss: 24.76258, reward_loss: 0.04009, value_loss: 0.00357 action_loss: -5.46935
# update_step:  27 model loss: 26.01482, kl_loss: 4.22667, obs_loss: 21.74887, reward_loss: 0.03928, value_loss: 0.00351 action_loss: -5.43947
# update_step:  28 model loss: 24.29366, kl_loss: 4.18931, obs_loss: 20.06289, reward_loss: 0.04145, value_loss: 0.00286 action_loss: -5.53700
# update_step:  29 model loss: 34.39314, kl_loss: 4.65760, obs_loss: 29.69477, reward_loss: 0.04077, value_loss: 0.00271 action_loss: -5.53474
# update_step:  30 model loss: 28.42161, kl_loss: 4.41977, obs_loss: 23.96188, reward_loss: 0.03996, value_loss: 0.00292 action_loss: -5.56081
# update_step:  31 model loss: 23.21190, kl_loss: 4.10606, obs_loss: 19.06458, reward_loss: 0.04126, value_loss: 0.00342 action_loss: -5.56659
# update_step:  32 model loss: 26.71605, kl_loss: 4.09054, obs_loss: 22.58165, reward_loss: 0.04387, value_loss: 0.00370 action_loss: -5.60678
# update_step:  33 model loss: 30.08765, kl_loss: 4.36718, obs_loss: 25.68100, reward_loss: 0.03947, value_loss: 0.00544 action_loss: -5.56035
# update_step:  34 model loss: 28.18327, kl_loss: 4.22292, obs_loss: 23.91905, reward_loss: 0.04130, value_loss: 0.00633 action_loss: -5.54821
# update_step:  35 model loss: 31.50853, kl_loss: 4.36202, obs_loss: 27.10691, reward_loss: 0.03960, value_loss: 0.00656 action_loss: -5.51645
# update_step:  36 model loss: 24.70528, kl_loss: 4.38965, obs_loss: 20.27478, reward_loss: 0.04085, value_loss: 0.00735 action_loss: -5.49376
# update_step:  37 model loss: 24.52567, kl_loss: 4.09390, obs_loss: 20.39201, reward_loss: 0.03976, value_loss: 0.00742 action_loss: -5.43153
# ...
# update_step:  89 model loss: 15.02300, kl_loss: 4.26316, obs_loss: 10.72140, reward_loss: 0.03844, value_loss: 0.01990 action_loss: -5.28512
# update_step:  90 model loss: 16.35775, kl_loss: 4.42546, obs_loss: 11.89283, reward_loss: 0.03946, value_loss: 0.00988 action_loss: -5.25037
# update_step:  91 model loss: 15.98056, kl_loss: 4.23858, obs_loss: 11.70379, reward_loss: 0.03820, value_loss: 0.00742 action_loss: -5.16029
# update_step:  92 model loss: 16.65650, kl_loss: 4.39718, obs_loss: 12.21983, reward_loss: 0.03949, value_loss: 0.01507 action_loss: -5.20412
# update_step:  93 model loss: 15.13372, kl_loss: 4.05317, obs_loss: 11.03984, reward_loss: 0.04070, value_loss: 0.01349 action_loss: -5.10663
# update_step:  94 model loss: 16.31340, kl_loss: 4.31063, obs_loss: 11.96230, reward_loss: 0.04047, value_loss: 0.01488 action_loss: -5.09626
# update_step:  95 model loss: 18.46378, kl_loss: 4.30393, obs_loss: 14.11886, reward_loss: 0.04100, value_loss: 0.01701 action_loss: -5.03509
# update_step:  96 model loss: 17.28485, kl_loss: 4.38300, obs_loss: 12.86241, reward_loss: 0.03944, value_loss: 0.01740 action_loss: -5.12194
# update_step:  97 model loss: 17.80016, kl_loss: 4.56050, obs_loss: 13.19946, reward_loss: 0.04020, value_loss: 0.02360 action_loss: -5.28566
# update_step:  98 model loss: 18.18976, kl_loss: 4.44477, obs_loss: 13.70700, reward_loss: 0.03798, value_loss: 0.02808 action_loss: -5.20646
# update_step:  99 model loss: 18.72175, kl_loss: 4.45574, obs_loss: 14.22655, reward_loss: 0.03947, value_loss: 0.02799 action_loss: -5.32150
# update_step: 100 model loss: 15.93355, kl_loss: 4.51440, obs_loss: 11.37873, reward_loss: 0.04041, value_loss: 0.02194 action_loss: -5.33766
# elasped time for update: 84.52s
# episode [  21/  21] is collected. Total reward is 48.849545
# elasped time for interaction: 0.22s
# update_step:   1 model loss: 17.04913, kl_loss: 4.39265, obs_loss: 12.61610, reward_loss: 0.04038, value_loss: 0.01388 action_loss: -5.43152
# update_step:   2 model loss: 16.52130, kl_loss: 4.30297, obs_loss: 12.18102, reward_loss: 0.03731, value_loss: 0.01268 action_loss: -5.41752
# update_step:   3 model loss: 15.38137, kl_loss: 4.20843, obs_loss: 11.13366, reward_loss: 0.03928, value_loss: 0.01064 action_loss: -5.44937
# update_step:   4 model loss: 18.24095, kl_loss: 4.53467, obs_loss: 13.66813, reward_loss: 0.03815, value_loss: 0.00843 action_loss: -5.53863
# update_step:   5 model loss: 17.23365, kl_loss: 4.52022, obs_loss: 12.67470, reward_loss: 0.03873, value_loss: 0.01019 action_loss: -5.51231
# update_step:   6 model loss: 17.04555, kl_loss: 4.47119, obs_loss: 12.53522, reward_loss: 0.03914, value_loss: 0.01404 action_loss: -5.54888
# update_step:   7 model loss: 17.48640, kl_loss: 4.39947, obs_loss: 13.04708, reward_loss: 0.03985, value_loss: 0.01963 action_loss: -5.58167
# update_step:   8 model loss: 16.80006, kl_loss: 4.55751, obs_loss: 12.20389, reward_loss: 0.03866, value_loss: 0.01561 action_loss: -5.60245
# update_step:   9 model loss: 14.99291, kl_loss: 4.22321, obs_loss: 10.72947, reward_loss: 0.04023, value_loss: 0.02121 action_loss: -5.61290
# update_step:  10 model loss: 16.91530, kl_loss: 4.15400, obs_loss: 12.72142, reward_loss: 0.03988, value_loss: 0.02541 action_loss: -5.62571
# update_step:  11 model loss: 16.94442, kl_loss: 4.23996, obs_loss: 12.66270, reward_loss: 0.04175, value_loss: 0.02542 action_loss: -5.61145
# update_step:  12 model loss: 16.35264, kl_loss: 4.41970, obs_loss: 11.89239, reward_loss: 0.04054, value_loss: 0.01308 action_loss: -5.51117
# update_step:  13 model loss: 15.25999, kl_loss: 4.32281, obs_loss: 10.89681, reward_loss: 0.04037, value_loss: 0.01134 action_loss: -5.54396
# update_step:  14 model loss: 14.83514, kl_loss: 4.18847, obs_loss: 10.60658, reward_loss: 0.04009, value_loss: 0.01018 action_loss: -5.57317
# update_step:  15 model loss: 16.28715, kl_loss: 4.44686, obs_loss: 11.80252, reward_loss: 0.03778, value_loss: 0.01175 action_loss: -5.51192
# update_step:  16 model loss: 15.41803, kl_loss: 4.30578, obs_loss: 11.07242, reward_loss: 0.03983, value_loss: 0.01160 action_loss: -5.50654
# update_step:  17 model loss: 17.92562, kl_loss: 4.45243, obs_loss: 13.43648, reward_loss: 0.03672, value_loss: 0.01377 action_loss: -5.53734
# update_step:  18 model loss: 15.58779, kl_loss: 4.16533, obs_loss: 11.37851, reward_loss: 0.04395, value_loss: 0.01659 action_loss: -5.48353
# update_step:  19 model loss: 17.81512, kl_loss: 4.35044, obs_loss: 13.42519, reward_loss: 0.03949, value_loss: 0.01276 action_loss: -5.47151
# update_step:  20 model loss: 17.55707, kl_loss: 4.64500, obs_loss: 12.87305, reward_loss: 0.03902, value_loss: 0.01507 action_loss: -5.35304
# update_step:  21 model loss: 17.04793, kl_loss: 4.40109, obs_loss: 12.60641, reward_loss: 0.04043, value_loss: 0.01491 action_loss: -5.40767
# update_step:  22 model loss: 15.87888, kl_loss: 4.23608, obs_loss: 11.60229, reward_loss: 0.04051, value_loss: 0.01124 action_loss: -5.38428
# update_step:  23 model loss: 17.56143, kl_loss: 4.33889, obs_loss: 13.18090, reward_loss: 0.04165, value_loss: 0.01701 action_loss: -5.34089
# update_step:  24 model loss: 15.74160, kl_loss: 4.35732, obs_loss: 11.34445, reward_loss: 0.03982, value_loss: 0.01862 action_loss: -5.41042
# update_step:  25 model loss: 16.62688, kl_loss: 4.31348, obs_loss: 12.27654, reward_loss: 0.03686, value_loss: 0.02225 action_loss: -5.46894
# update_step:  26 model loss: 17.29928, kl_loss: 4.44407, obs_loss: 12.81379, reward_loss: 0.04142, value_loss: 0.02096 action_loss: -5.52473
# update_step:  27 model loss: 16.93379, kl_loss: 4.39935, obs_loss: 12.49212, reward_loss: 0.04233, value_loss: 0.01994 action_loss: -5.56200
# update_step:  28 model loss: 14.51030, kl_loss: 4.19399, obs_loss: 10.27634, reward_loss: 0.03997, value_loss: 0.01343 action_loss: -5.48850
# update_step:  29 model loss: 15.99111, kl_loss: 4.30354, obs_loss: 11.64828, reward_loss: 0.03929, value_loss: 0.01534 action_loss: -5.53742
# update_step:  30 model loss: 15.89011, kl_loss: 4.42212, obs_loss: 11.42610, reward_loss: 0.04189, value_loss: 0.01554 action_loss: -5.47908
# update_step:  31 model loss: 17.67668, kl_loss: 4.49274, obs_loss: 13.14441, reward_loss: 0.03953, value_loss: 0.00967 action_loss: -5.60184
# update_step:  32 model loss: 18.38532, kl_loss: 4.35151, obs_loss: 13.99720, reward_loss: 0.03662, value_loss: 0.01037 action_loss: -5.60032
# update_step:  33 model loss: 17.29660, kl_loss: 4.34260, obs_loss: 12.91500, reward_loss: 0.03900, value_loss: 0.01063 action_loss: -5.59022
# update_step:  34 model loss: 15.88123, kl_loss: 4.27881, obs_loss: 11.56222, reward_loss: 0.04019, value_loss: 0.00866 action_loss: -5.56886
# update_step:  35 model loss: 18.08834, kl_loss: 4.30346, obs_loss: 13.74679, reward_loss: 0.03809, value_loss: 0.00936 action_loss: -5.51606
# update_step:  36 model loss: 16.56875, kl_loss: 4.19064, obs_loss: 12.33716, reward_loss: 0.04095, value_loss: 0.00877 action_loss: -5.55016
# update_step:  37 model loss: 17.58104, kl_loss: 4.20986, obs_loss: 13.33164, reward_loss: 0.03954, value_loss: 0.00972 action_loss: -5.68687
# update_step:  38 model loss: 16.54560, kl_loss: 4.25226, obs_loss: 12.25419, reward_loss: 0.03915, value_loss: 0.01187 action_loss: -5.57296
# update_step:  39 model loss: 15.80948, kl_loss: 4.20017, obs_loss: 11.56989, reward_loss: 0.03942, value_loss: 0.01145 action_loss: -5.55723
# update_step:  40 model loss: 17.31001, kl_loss: 4.41232, obs_loss: 12.85664, reward_loss: 0.04106, value_loss: 0.00997 action_loss: -5.52761
# update_step:  41 model loss: 15.65373, kl_loss: 4.41719, obs_loss: 11.19835, reward_loss: 0.03819, value_loss: 0.00887 action_loss: -5.60657
# update_step:  42 model loss: 18.04599, kl_loss: 4.51040, obs_loss: 13.49706, reward_loss: 0.03852, value_loss: 0.01249 action_loss: -5.46215
# update_step:  43 model loss: 17.32882, kl_loss: 4.38602, obs_loss: 12.90198, reward_loss: 0.04082, value_loss: 0.01251 action_loss: -5.55961
# update_step:  44 model loss: 17.35601, kl_loss: 4.41680, obs_loss: 12.89970, reward_loss: 0.03951, value_loss: 0.01675 action_loss: -5.40245
# update_step:  45 model loss: 16.60466, kl_loss: 4.48433, obs_loss: 12.08189, reward_loss: 0.03844, value_loss: 0.01348 action_loss: -5.37412
# update_step:  46 model loss: 16.93771, kl_loss: 4.44390, obs_loss: 12.45618, reward_loss: 0.03763, value_loss: 0.01066 action_loss: -5.34008
# update_step:  47 model loss: 15.61456, kl_loss: 4.31212, obs_loss: 11.26031, reward_loss: 0.04213, value_loss: 0.01184 action_loss: -5.38865
# update_step:  48 model loss: 17.12770, kl_loss: 4.35494, obs_loss: 12.73233, reward_loss: 0.04044, value_loss: 0.01433 action_loss: -5.29866
# update_step:  49 model loss: 16.11983, kl_loss: 4.30682, obs_loss: 11.77122, reward_loss: 0.04180, value_loss: 0.01147 action_loss: -5.37810
# update_step:  50 model loss: 16.20696, kl_loss: 4.60814, obs_loss: 11.56089, reward_loss: 0.03794, value_loss: 0.01677 action_loss: -5.24435
# update_step:  51 model loss: 15.08474, kl_loss: 4.36659, obs_loss: 10.67846, reward_loss: 0.03969, value_loss: 0.01492 action_loss: -5.23958
# update_step:  52 model loss: 14.31461, kl_loss: 4.31551, obs_loss: 9.95894, reward_loss: 0.04016, value_loss: 0.02363 action_loss: -5.36378
# update_step:  53 model loss: 16.19169, kl_loss: 4.56211, obs_loss: 11.59019, reward_loss: 0.03939, value_loss: 0.02290 action_loss: -5.39639
# update_step:  54 model loss: 17.12562, kl_loss: 4.48927, obs_loss: 12.59675, reward_loss: 0.03960, value_loss: 0.01917 action_loss: -5.29099
# update_step:  55 model loss: 17.03248, kl_loss: 4.31745, obs_loss: 12.67485, reward_loss: 0.04018, value_loss: 0.02201 action_loss: -5.37630
# update_step:  56 model loss: 15.48227, kl_loss: 4.34622, obs_loss: 11.09440, reward_loss: 0.04165, value_loss: 0.01359 action_loss: -5.32546
# update_step:  57 model loss: 17.79903, kl_loss: 4.50278, obs_loss: 13.25601, reward_loss: 0.04025, value_loss: 0.01389 action_loss: -5.30935
# update_step:  58 model loss: 16.01490, kl_loss: 4.40047, obs_loss: 11.57573, reward_loss: 0.03869, value_loss: 0.01043 action_loss: -5.34445
# update_step:  59 model loss: 15.39860, kl_loss: 4.40288, obs_loss: 10.95607, reward_loss: 0.03965, value_loss: 0.01116 action_loss: -5.38552
# update_step:  60 model loss: 14.33127, kl_loss: 4.27160, obs_loss: 10.01943, reward_loss: 0.04024, value_loss: 0.01280 action_loss: -5.47423
# update_step:  61 model loss: 15.84640, kl_loss: 4.31717, obs_loss: 11.49038, reward_loss: 0.03885, value_loss: 0.01460 action_loss: -5.40152
# update_step:  62 model loss: 16.76135, kl_loss: 4.47840, obs_loss: 12.24296, reward_loss: 0.03999, value_loss: 0.01110 action_loss: -5.43799
# update_step:  63 model loss: 15.66427, kl_loss: 4.29230, obs_loss: 11.33208, reward_loss: 0.03989, value_loss: 0.01341 action_loss: -5.41106
# update_step:  64 model loss: 15.66985, kl_loss: 4.24158, obs_loss: 11.38723, reward_loss: 0.04104, value_loss: 0.02047 action_loss: -5.45031
# update_step:  65 model loss: 14.94446, kl_loss: 4.14554, obs_loss: 10.76117, reward_loss: 0.03775, value_loss: 0.01088 action_loss: -5.47043
# update_step:  66 model loss: 16.31706, kl_loss: 4.19338, obs_loss: 12.08518, reward_loss: 0.03850, value_loss: 0.01219 action_loss: -5.54395
# update_step:  67 model loss: 16.46062, kl_loss: 4.14356, obs_loss: 12.27473, reward_loss: 0.04233, value_loss: 0.01040 action_loss: -5.50190
# update_step:  68 model loss: 18.94760, kl_loss: 4.60668, obs_loss: 14.30102, reward_loss: 0.03990, value_loss: 0.01568 action_loss: -5.42640
# update_step:  69 model loss: 16.84813, kl_loss: 4.40119, obs_loss: 12.40729, reward_loss: 0.03966, value_loss: 0.01654 action_loss: -5.40723
# update_step:  70 model loss: 17.81071, kl_loss: 4.38662, obs_loss: 13.38259, reward_loss: 0.04150, value_loss: 0.02608 action_loss: -5.26200
# update_step:  71 model loss: 15.68549, kl_loss: 4.25224, obs_loss: 11.39124, reward_loss: 0.04202, value_loss: 0.02213 action_loss: -5.32087
# update_step:  72 model loss: 17.26467, kl_loss: 4.58255, obs_loss: 12.64162, reward_loss: 0.04050, value_loss: 0.01634 action_loss: -5.33951
# update_step:  73 model loss: 17.49561, kl_loss: 4.21565, obs_loss: 13.23842, reward_loss: 0.04154, value_loss: 0.01249 action_loss: -5.29110
# update_step:  74 model loss: 16.98803, kl_loss: 4.21464, obs_loss: 12.73569, reward_loss: 0.03770, value_loss: 0.00949 action_loss: -5.30440
# update_step:  75 model loss: 15.71494, kl_loss: 4.17093, obs_loss: 11.50445, reward_loss: 0.03956, value_loss: 0.01389 action_loss: -5.36627
# update_step:  76 model loss: 17.60821, kl_loss: 4.27168, obs_loss: 13.29754, reward_loss: 0.03900, value_loss: 0.01387 action_loss: -5.28238
# update_step:  77 model loss: 16.65309, kl_loss: 4.20193, obs_loss: 12.41071, reward_loss: 0.04045, value_loss: 0.01184 action_loss: -5.15893
# update_step:  78 model loss: 16.35620, kl_loss: 4.37545, obs_loss: 11.94182, reward_loss: 0.03893, value_loss: 0.02305 action_loss: -5.44241
# update_step:  79 model loss: 18.13723, kl_loss: 4.49540, obs_loss: 13.60494, reward_loss: 0.03689, value_loss: 0.01943 action_loss: -5.32001
# update_step:  80 model loss: 16.02470, kl_loss: 4.40123, obs_loss: 11.58105, reward_loss: 0.04242, value_loss: 0.01657 action_loss: -5.20721
# update_step:  81 model loss: 18.31555, kl_loss: 4.44624, obs_loss: 13.82906, reward_loss: 0.04025, value_loss: 0.01684 action_loss: -5.16479
# update_step:  82 model loss: 15.76945, kl_loss: 4.07153, obs_loss: 11.65832, reward_loss: 0.03960, value_loss: 0.01601 action_loss: -5.24309
# update_step:  83 model loss: 16.64191, kl_loss: 4.34385, obs_loss: 12.25816, reward_loss: 0.03991, value_loss: 0.01530 action_loss: -5.19188
# update_step:  84 model loss: 16.58939, kl_loss: 4.27253, obs_loss: 12.27558, reward_loss: 0.04129, value_loss: 0.01252 action_loss: -5.28428
# update_step:  85 model loss: 17.40394, kl_loss: 4.50951, obs_loss: 12.85654, reward_loss: 0.03790, value_loss: 0.01356 action_loss: -5.21940
# update_step:  86 model loss: 16.91465, kl_loss: 4.28279, obs_loss: 12.59332, reward_loss: 0.03855, value_loss: 0.01246 action_loss: -5.33886
# update_step:  87 model loss: 18.83812, kl_loss: 4.52956, obs_loss: 14.27096, reward_loss: 0.03759, value_loss: 0.01497 action_loss: -5.40954
# update_step:  88 model loss: 17.55070, kl_loss: 4.38539, obs_loss: 13.12613, reward_loss: 0.03918, value_loss: 0.01360 action_loss: -5.39134
# update_step:  89 model loss: 17.12583, kl_loss: 4.47958, obs_loss: 12.60703, reward_loss: 0.03922, value_loss: 0.01841 action_loss: -5.40358
# update_step:  90 model loss: 16.31311, kl_loss: 4.18898, obs_loss: 12.08363, reward_loss: 0.04049, value_loss: 0.01265 action_loss: -5.42790
# update_step:  91 model loss: 18.71607, kl_loss: 4.61893, obs_loss: 14.05984, reward_loss: 0.03731, value_loss: 0.01576 action_loss: -5.42652
# update_step:  92 model loss: 17.09769, kl_loss: 4.31935, obs_loss: 12.74194, reward_loss: 0.03640, value_loss: 0.01216 action_loss: -5.33511
# update_step:  93 model loss: 18.30209, kl_loss: 4.40724, obs_loss: 13.85756, reward_loss: 0.03729, value_loss: 0.01356 action_loss: -5.45851
# update_step:  94 model loss: 15.88681, kl_loss: 4.55043, obs_loss: 11.29625, reward_loss: 0.04013, value_loss: 0.01113 action_loss: -5.30831
# update_step:  95 model loss: 16.40508, kl_loss: 4.39260, obs_loss: 11.97289, reward_loss: 0.03959, value_loss: 0.01214 action_loss: -5.40409
# update_step:  96 model loss: 17.16695, kl_loss: 4.37715, obs_loss: 12.74942, reward_loss: 0.04038, value_loss: 0.01412 action_loss: -5.42209
# update_step:  97 model loss: 17.14933, kl_loss: 4.29019, obs_loss: 12.81927, reward_loss: 0.03987, value_loss: 0.01668 action_loss: -5.48811
# update_step:  98 model loss: 16.24998, kl_loss: 4.36450, obs_loss: 11.84491, reward_loss: 0.04057, value_loss: 0.01639 action_loss: -5.48058
# update_step:  99 model loss: 16.09968, kl_loss: 4.25318, obs_loss: 11.80640, reward_loss: 0.04011, value_loss: 0.01880 action_loss: -5.60185
# update_step: 100 model loss: 18.51978, kl_loss: 4.60064, obs_loss: 13.87998, reward_loss: 0.03916, value_loss: 0.01344 action_loss: -5.47369
# elasped time for update: 83.79s

# %% [markdown]
# TensorBoardで学習結果を確認してみます.

# %%
# %tensorboard --logdir='./logs'

# %% [markdown]
# # observationの復元
#
# 以下が追加部分です。2023-03-02版のコードは関数定義以外を削除して、新たにセルを追加しています。(2023-03-06: 福田)

# %% [markdown]
# 以下の2関数は2023-03-02版と同様です。

# %%
def depreprocess_obs(obs):
    """
    preprocess_obsで処理されたデータを元の画像に戻す
    """
    # (3, 128, 128) のtensorを (128, 128, 3) の形に変換する
    obs = obs.permute(1, 2, 0)

    # 値域を [-0.5, 0.5] -> [0, 255] に変換する
    obs = (obs + 0.5) * 255

    return obs.to('cpu').detach().numpy().astype(np.uint8)

# %%
def make_video_from_images(images):
    """
    numpyのndarrayの配列を結合して動画にする
    （make_animation_from_images関数とほぼ同内容です）
    """
    fig = plt.figure(figsize=(3,3))

    imgs = []
    for image in images:
        img = plt.imshow(image, animated=True)
        plt.axis('off')
        imgs.append([img])

    anime = animation.ArtistAnimation(fig, imgs, interval=50, repeat_delay=1000)
    plt.close()
    return anime

# %% [markdown]
# ここからが2023-03-02版からの修正部分です。

# %%
policy = Agent(encoder, rssm.transition, action_model)

# hiddenに現実の情報を蓄積する
for split_df in split_dfs:
  for idx, row in split_df.iterrows():
    obs = np.array(Image.open(row.filename))
    policy(obs)

# %%
# obsをAgentに処理できる形式に変換する
# （Agentクラスの__call__の前段に相当する処理）
preprocessed_obs = preprocess_obs(obs)
preprocessed_obs = torch.as_tensor(preprocessed_obs, device=device)
preprocessed_obs = preprocessed_obs.transpose(1, 2).transpose(0, 1).unsqueeze(0)

# 観測を低次元の表現に変換する
# （Agentクラスの__call__の後段に相当する処理）
with torch.no_grad():
    embedded_obs = encoder(preprocessed_obs)
    rnn_hidden = policy.rnn_hidden
    state = rssm.transition.posterior(rnn_hidden, embedded_obs).sample()

images = []
prediction_length = 300 # 300フレーム予測する
for _ in range(prediction_length):
    action = policy(obs)
    with torch.no_grad():
        state_prior, rnn_hidden = rssm.transition.prior(rnn_hidden)
        state = state_prior.sample()
        predicted_obs = rssm.observation(state, rnn_hidden)

    images.append(depreprocess_obs(predicted_obs.squeeze()))

# %%
HTML(make_video_from_images([Image.fromarray(i) for i in images]).to_html5_video())
# Out:
# <video width="216" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...
